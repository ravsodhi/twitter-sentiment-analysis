# %% [markdown]
# **Created by Peter Nagy February 2017 [Github][1]**
#
# **Sentiment Analysis:** the process of computationally identifying and categorizing opinions expressed in a piece of text, especially in order to determine whether the writer's attitude towards a particular topic, product, etc. is positive, negative, or neutral.
#
#
#   [1]: https://github.com/nagypeterjob

# %% [markdown]
# As an improvement to my previous [Kernel][1], here I am trying to achieve better results with a Recurrent Neural Network.
#
#   [1]: https://www.kaggle.com/ngyptr/d/crowdflower/first-gop-debate-twitter-sentiment/python-nltk-sentiment-analysis

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load in 

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

from sklearn.feature_extraction.text import CountVectorizer
from keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences
from keras.models import Sequential
from keras.layers import Dense, Embedding, LSTM
from sklearn.model_selection import train_test_split
from keras.utils.np_utils import to_categorical
import re
from nltk.tokenize import TweetTokenizer
from nltk.corpus import stopwords
from sklearn.metrics import make_scorer, accuracy_score, f1_score, precision_score, recall_score
# Input data files are available in the "../input/" directory.
# For example, running this (by clicking run or pressing Shift+Enter) will list the files in the input directory

# %%
TRAIN_DATA = "../twitter-2016train-BD.txt"
DEV_DATA = "../twitter-2016dev-BD.txt"
TEST_DATA = "../twitter-2016test-BD.txt"
vocab = {}
reverse_vocab = {}
output_class = {}
# output_class[]
def readData(path):
    data = []
    with open(path) as file:
        data = file.read()
#         data = codecs.decode(data, 'unicode_escape')
        data = data.split('\n')[:-1]
    return data

def removePattern(tweet, pattern):
    r = re.findall(pattern, tweet)
    for i in r:
        tweet = re.sub(i, '', tweet)
    return tweet

def preprocess(data):
    cleanData = []
    for line in data:
#         print(line.split("\t"))
        tId, tAt, tSent, tweet = line.split("\t")[:4] # Splitting by tabspace
        tweet = removePattern(tweet, "@[\w]*") # Removing @user tags
        tweet = tweet.replace("#", "") # Removing '#' from hashtags
        tweet = tweet.replace("[^a-zA-Z#]", " ") # Removing punctuation and special characters
        tweet = re.sub(r'http[s]?://(?:[a-z]|[0-9]|[$-_@.&amp;+]|[!*\(\),]|(?:%[0-9a-f][0-9a-f]))+',"<URL>", tweet)
        tweet = re.sub(" +", " ", tweet)
        tweet = tweet.lower()
        x = TweetTokenizer().tokenize(tweet)
        for word in x:
            if word not in vocab:
                vocab[word] = len(vocab)
                reverse_vocab[len(vocab)] = word
        cleanData.append([tId, tAt, tSent, tweet])
    return cleanData

def tokenize(tweet):
    return TweetTokenizer().tokenize(tweet)

en_stopwords = set(stopwords.words("english"))
vectorizer = CountVectorizer(
    analyzer = 'word',
    tokenizer = tokenize,
    lowercase = True,
    ngram_range=(1, 1),
    vocabulary=vocab,
    stop_words = en_stopwords)

trainData   = readData(TRAIN_DATA)
testData   = readData(TEST_DATA)
devData   = readData(DEV_DATA)
# print(testData)

# %% [markdown]
# Only keeping the necessary columns.

# %%
# data = pd.read_csv('../Sentiment.csv')
# # Keeping only the neccessary columns
# data = data[['text','sentiment']]
# file = "../twitter-2016train-BD.txt"
# trainData
trainData   = preprocess(trainData)
testData = preprocess(testData)
devData = preprocess(devData)
testData
# Out:
# [['681563394940473347',
#   'amy schumer',
#   'negative',
#   " amy schumer is the stereotypical 1st world laci green feminazi. plus she's unfunny"],
#  ['675847244747177984',
#   'amy schumer',
#   'negative',
#   " i mean i get the hype around jlaw. i may not like her but i get her hype. i just don't understand amy schumer and her hype"],
#  ['672827854279843840',
#   'amy schumer',
#   'negative',
#   'amy schumer at the gqmenoftheyear2015 party in a dress we pretty much hate: <url> gqmoty2015 <url>'],
#  ['662755012129529858',
#   'amy schumer',
#   'negative',
#   "amy schumer is on sky atlantic doing one of the worst stand up sets i have ever seen. and i've almost sat through 30 seconds of millican."],
#  ['671502639671042048',
#   'amy schumer',
#   'negative',
#   '"amy schumer may have brought us trainwreck, but that word just got redefined on thevoice."'],
#  ['677359143108214784',
#   'amy schumer',
#   'negative',
#   'i just think that sports are stupid &amp;anyone who likes them is a lesser person &amp; has a small intellect- amy schumer <url>'],
#  ['663714752162607104',
#   'amy schumer',
#   'negative',
#   '"if you do like amy schumer, i hope you went &amp; saw her saturday bc after this ridiculousness, i highly doubt maine will be on list of faves."'],
#  ['671468325617033216',
#   'amy schumer',
#   'negative',
#   '"people are like, ""amy schumer? i don\'t like her, she\'s fat."" and i\'m all like ralphie may is fatter, and i don\'t... <url>"'],
#  ['665033491445383168',
#   'amy schumer',
#   'negative',
#   '"seriously though, somebody posted amy schumer as their woman crush wednesday on instagram &amp; i almost went off, but it\'s not worth it"'],
#  ['678882295349190656',
#   'amy schumer',
#   'negative',
#   "they may be mean but i guess they're not stupid...free ted but you have to pay for amy schumer - most unimpressed. <url>"],
#  ['672070053509079040',
#   'amy schumer',
#   'negative',
#   'this amy schumer segment is now old news about 2 days too late...good producer would have had it on monday local24 lml'],
#  ['676724243296419841',
#   'amy schumer',
#   'negative',
#   'warning: this may not safe for work. but mojo &amp; ac just found out about some new amy schumer leaked nudes! <url>'],
#  ['673402172596465664',
#   'amy schumer',
#   'negative',
#   "if i have to read another article about how amy schumer is a feminist icon i'm going to fucking toss myself into the sun"],
#  ['678501579591315456',
#   'amy schumer',
#   'positive',
#   '"snl well it\'s a good thing i stumbled upon maya rudolph, amy schumer, paul mccartney &amp; bruce\'s 3rd after roh10man. cheeseburger kget"'],
#  ['671807490527502336',
#   'amy schumer',
#   'positive',
#   "'amy schumer' appeared on monday 30 at the 13th place in the top20 of los angeles's trends: <url> trndnl"],
#  ['672700570013212672',
#   'amy schumer',
#   'positive',
#   "...1st of all this is amy schumer and she's funnier and hotter than you will ever be 2nd of all shut the fuck up <url>"],
#  ['664438720825683969',
#   'amy schumer',
#   'positive',
#   "41 amy schumer quotes to get you through wednesday (she's pretty badass) <url> <url>"],
#  ['672601020476891136',
#   'amy schumer',
#   'positive',
#   "amy schumer tickets still available for sunday's show at kent state!! go to the <url> website! <url>"],
#  ['676567715033714691',
#   'amy schumer',
#   'positive',
#   'actress and comedian amy schumer shared an intimate portrait on monday that it will not quickly be forgotten.'],
#  ['666801300806463488',
#   'amy schumer',
#   'positive',
#   'amy schumer and jerry seinfeld headline a show in support of the 15th anniversary of baby buggy <url> via '],
#  ['674792039565819904',
#   'amy schumer',
#   'positive',
#   'amy schumer will be here friday &amp; i want to go!'],
#  ['676978809753739264',
#   'amy schumer',
#   'positive',
#   "amy schumer's honest post may actually inspire you to strip down: <url> <url>"],
#  ['675940555197689857',
#   'amy schumer',
#   'positive',
#   '"and my toughest final is tomorrow, it\'s cumulative, and i\'ve been watching amy schumer and the office all night instead of studying"'],
#  ['677981140343476224',
#   'amy schumer',
#   'positive',
#   "can't wait to see amy schumer with tomorrow!"],
#  ['673355896580268032',
#   'amy schumer',
#   'positive',
#   '"demi lovato praises amy schumer on 2016 pirelli calendar photo: on thursday night, the comedian spoke ... <url> lovato"'],
#  ['671848363139055616',
#   'amy schumer',
#   'positive',
#   "did you know that 'amy schumer' was trending topic on monday 30 for 4 hours in united states? <url> trndnl"],
#  ['676206685707481088',
#   'amy schumer',
#   'positive',
#   '"done with ahs till wednesday &amp; finished inside amy schumer, now what?"'],
#  ['675100987342876673',
#   'amy schumer',
#   'positive',
#   '"for those that wanna see inside amy schumer\'s golden globes , it may happen! cantwait <url>"'],
#  ['670804003328929792',
#   'amy schumer',
#   'positive',
#   '"from my 2nd family, katherine m., a student in nyc, got an internship with amy schumer...now that\'s cool."'],
#  ['675435336324005888',
#   'amy schumer',
#   'positive',
#   "going to see amy schumer in nashville tonight. but don't worry i got your epl plays over on <url>"],
#  ['672982999953252352',
#   'amy schumer',
#   'positive',
#   "i get to see amy schumer live tomorrow. i'm literally the luckiest girl on planet earth"],
#  ['672474804306501634',
#   'amy schumer',
#   'positive',
#   'i just want it to be saturday so amy schumer can make me laugh and feel good about my life compared to hers.'],
#  ['663661476729647104',
#   'amy schumer',
#   'positive',
#   '"i think i may have just fell in love with after watching ""amy schumer: live...extended cut"" on ."'],
#  ['664935231535886336',
#   'amy schumer',
#   'positive',
#   '"i\'m just really excited for my comedy filled day tomorrow... amy schumer live and john mulaney on netflix?! thank you, america."'],
#  ['679647483182592000',
#   'amy schumer',
#   'positive',
#   'inside amy schumer is scorching its merry way back onto in the new year. s3 begins on jan 11 at 11pm. (s2 still on demand.)'],
#  ['678239954527510530',
#   'amy schumer',
#   'positive',
#   'it was a wild night at jazz at the bistro. amy schumer &amp; cast dug our 2nd set &amp; had a comedy jam- epic! <url>'],
#  ['674624716368429056',
#   'amy schumer',
#   'positive',
#   '"kerry washington, viola davis, amy schumer and jill soloway all make power 100 list for 1st time. changingtheworld"'],
#  ['678044458286477312',
#   'amy schumer',
#   'positive',
#   'kind of equally excited at staying in watching the soup finale tonight as i am for going out to see amy schumer tomorrow. well...kind of'],
#  ['678038033975934976',
#   'amy schumer',
#   'positive',
#   'on saturday night live set today with amy schumer! <url>'],
#  ['678412420679864320',
#   'amy schumer',
#   'positive',
#   '"one of the 1st jokes from the hilarious amy schumer at : ""if anybody thought they were seeing \'godspell\' tonight, maybe exit left."""'],
#  ['662320812444295169',
#   'amy schumer',
#   'positive',
#   'outrageously funny: amy schumer plays mohegan sun tonight <url> via '],
#  ['674320406195519492',
#   'amy schumer',
#   'positive',
#   '"pga awards tv nominations include better call saul, mad men and inside amy schumer: on tuesday, the ... <url> tvupdate"'],
#  ['661024625237864448',
#   'amy schumer',
#   'positive',
#   'photos: beautiful! selena presenting amy schumer with an award at the 19th annual hollywood film awards! <url>'],
#  ['661830516644052992',
#   'amy schumer',
#   'positive',
#   'saw trainwreck for the 2nd time &amp; again found it &amp; amy schumer brilliant as was the screenplay she wrote. mel brooks agreed.100%'],
#  ['661846107648040960',
#   'amy schumer',
#   'positive',
#   'selena gomez presented amy schumer with an award and a heap of praise at the hollywood film awards on november 1.'],
#  ['664156554397007872',
#   'amy schumer',
#   'positive',
#   '"selena gomez, amy schumer get cuddly on the red carpet: see the cuteness here!: <url> videos may"'],
#  ['663498474680381440',
#   'amy schumer',
#   'positive',
#   "some may find it tragic that i'm sat alone watching amy schumer and eating ben and jerries but personally i feel no shame"],
#  ['667138890017452032',
#   'amy schumer',
#   'positive',
#   'the only reason i keep going is that i get to see amy schumer in june'],
#  ['678074631576653824',
#   'amy schumer',
#   'positive',
#   '"watching ""trainwreck"" for the 2nd time with my girls. hilarious!!! love amy schumer! trainwreck johncena amyschumer"'],
#  ['672588385438081024',
#   'amy schumer',
#   'positive',
#   '"watching \'inside amy schumer\' for the 1st time. she\'s funny, sassy, smart, beautiful...&amp; sleeps with a teddy bear in one sketch. i\'m hooked."'],
#  ['668188104235352065',
#   'amy schumer',
#   'positive',
#   'watching amy schumer for the 1st time...so funny! i must have been living under a rock or something'],
#  ['672542335834583040',
#   'amy schumer',
#   'positive',
#   'watching amy schumer: live at the apollo makes me so excited for sunday when brings '],
#  ['680277505677340672',
#   'amy schumer',
#   'positive',
#   '"watching the pogues\'s ""fairytale of ny"" for the 9th time today and is it just me or does kirsty maccoll look kinda like amy schumer?"'],
#  ['672683051248451584',
#   'amy schumer',
#   'positive',
#   "well kid's it's friday. so rejoice. another week is done. the hell with trump i'm voting for amy schumer.. white house bound "],
#  ['673513230044647424',
#   'amy schumer',
#   'positive',
#   '"when it comes to body empowerment and feeling comfortable in your own skin, amy schumer is the role model we look up to. on thursday"'],
#  ['666324759290998784',
#   'amy schumer',
#   'positive',
#   "who was the best 'saturday night live' host? amy schumer. 50% of voters agree with me. <url>"],
#  ['663766498154967040',
#   'amy schumer',
#   'positive',
#   'who went to the first amy schumer show on saturday? anyone who would be willing to talk to me about it? <url>'],
#  ['661216075451793408',
#   'amy schumer',
#   'positive',
#   '"will smith, amy schumer and carey mulligan were among those honoured sunday at the hollywood film awards, with... <url>"'],
#  ['679507103346601984',
#   'amy schumer',
#   'positive',
#   '"in them to do it. amy schumer in ew, october is a fucking rock star &amp; i love her &amp; jesus f\'ing christ we need more like this"'],
#  ['671386913727758336',
#   'amy schumer',
#   'positive',
#   "just another reason to love amy schumer and here's a piece on the calendar.. <url> <url>"],
#  ['635430416737017856',
#   'ant-man',
#   'negative',
#   '"more meta-textually, ant-man may be the worst movie in the marvel universe for gender roles. of its... <url>"'],
#  ['627893322196107265',
#   'ant-man',
#   'negative',
#   "ant-man was the 1st time i didn't stay for a marvel film's post credits scene. the film was just one big teaser. didn't need to see another."],
#  ['625640680778518528',
#   'ant-man',
#   'negative',
#   'as ridiculous as ant-man may have looked it was actually pretty damn good bigfan'],
#  ['636801279210180609',
#   'ant-man',
#   'negative',
#   '"more meta-textually, ant-man may be the worst movie in the marvel universe for gender roles. of its... <url>"'],
#  ['626338341261213696',
#   'ant-man',
#   'negative',
#   '"podgodz 165: podgodz 165 recorded 28 july 2015 i saw ant-man, i should not have. midroll sells to, i want to s... <url>"'],
#  ['626045838842793984',
#   'ant-man',
#   'negative',
#   "reason why ant-man may have 'struggled' vs. other marvel? my parents assumed it was a parody."],
#  ['626206832927842304',
#   'ant-man',
#   'negative',
#   '"sorry gang, 2nd act of ant-man just kills my buzz. so boring and the writing is really bad. i\'m hoping this stuff wasn\'t in wright\'s script."'],
#  ['626170746096779264',
#   'ant-man',
#   'negative',
#   "the only reason i'm watching ant-man is cause of 5$ tuesday this is definitely something you wait to watch at home"],
#  ['635366736510869505',
#   'ant-man',
#   'positive',
#   ": can't spell star hotshots without the word short. go ant-man!!! <url>"],
#  ['639677138598146050',
#   'ant-man',
#   'positive',
#   '"smartncaa: it\'s another \'yes para sa tres\' for the ""ant-man"" mark cruz! letran stil on top, 72-53 with 1:53 remaining in the 4th!"'],
#  ['639677997021159424',
#   'ant-man',
#   'positive',
#   '"smartncaa: it\'s another \'yes para sa tres\' for the ""ant-man"" mark cruz! letran still on top, 72-53 with 1:53 remaining in the 4th!"'],
#  ['628636707148197890',
#   'ant-man',
#   'positive',
#   '"// -- cinema this saturday. i would love to see ant-man, but he\'s not into marvel like i am, so i believe i\'m gonna have to give it a miss."'],
#  ['628653717634596864',
#   'ant-man',
#   'positive',
#   '"// so, i thought ant-man was out of the question for the cinema saturday but my boyfriend said the films he\'s seen are \'awesome\' and that -"'],
#  ['625393778640199680',
#   'ant-man',
#   'positive',
#   '"3rd time. antman with friends ( rogers 18 theater for ant-man in rogers, mn) <url>"'],
#  ['626151908823158784',
#   'ant-man',
#   'positive',
#   "5 days off now! bit of golf on the agenda and a few other bits. looking forward to watching 's ant-man on thursday too!"],
#  ['625481250652995584',
#   'ant-man',
#   'positive',
#   " i've got mon. off work &amp; i'm going to see ant-man movie in theaters. want to see it in 3d."],
#  ['628027843834834944',
#   'ant-man',
#   'positive',
#   ' saw ant-man at amc eastchase 9 in fort worth. 1st time at the theater. great experience for my wife and me!'],
#  ['629613672474779648',
#   'ant-man',
#   'positive',
#   '" here it\'s 1:20 pm, i can be around that time but maaaybe i\'ll be gone since i may watch ant-man today"'],
#  ['629374081096384512',
#   'ant-man',
#   'positive',
#   ' i finally saw ant-man on tuesday it was so good &amp; entertaining also i enjoyed the spider-man reference'],
#  ['627319322227154944',
#   'ant-man',
#   'positive',
#   " we're going to see ant-man tomorrow. i figured it would seem even better in comparison after watching this. :)"],
#  ['625797977563635712',
#   'ant-man',
#   'positive',
#   " just watched the show. great show. couldn't agree it's about ant-man. see ya thursday"],
#  ['625476777809432576',
#   'ant-man',
#   'positive',
#   ' ant-man was 1 for the 2nd straight week domestically. never has this been more apropos. <url>'],
#  ['626214291012755456',
#   'ant-man',
#   'positive',
#   " so i'm a bit late but i watched ant-man. it was amazing and great job! can't wait for the 2nd one!"],
#  ['626312003993358336',
#   'ant-man',
#   'positive',
#   '" hi eve, i hope you enjoyed ant-man! saverday tuesday is all day &amp; prices can be found here in future: <url>"'],
#  ['627571145039028224',
#   'ant-man',
#   'positive',
#   '" i went to see mission impossible rouge nation today, i really enjoyed it. have u seen it? i might go see ant-man tomorrow?"'],
#  ['627244872714559488',
#   'ant-man',
#   'positive',
#   '" i had high expectactions when i watched because everyone was hyping it so much, i knew ant-man would be good after 1st trailer"'],
#  ['626242760979320832',
#   'ant-man',
#   'positive',
#   '" you definitely aren\'t, ant-man was my 2nd favorite phase 2 flick right after winter soldier"'],
#  ['632877462096101376',
#   'ant-man',
#   'positive',
#   ' took my son to see ant-man yesterday and the forceawakens trailer played before. 1st time seeing it on big screen. awesome'],
#  ['627193103670222848',
#   'ant-man',
#   'positive',
#   '" probably see ant-man at the cinema tomorrow. ) i hope you enjoy your tea, i\'m certain you will. x"'],
#  ['629462412933005312',
#   'ant-man',
#   'positive',
#   '" there are a few winks in winter soldier and ant-man, various iron mans. largely, though, you may be right."'],
#  ['632244608253206529',
#   'ant-man',
#   'positive',
#   '" i am so hyped for tomorrow, the clip at the end of ant-man was enough to get me excited"'],
#  ['636484004930289664',
#   'ant-man',
#   'positive',
#   " they are great aren't they - i have one from the ant-man wave coming tomorrow as i want to build the ultron figure."],
#  ['634181949603491840',
#   'ant-man',
#   'positive',
#   '" yeah, ant-man fails on jan and her daughter, but it\'s still a better movie than ff according to reviewers i trust."'],
#  ['628962483060011008',
#   'ant-man',
#   'positive',
#   '" horrible. diehard fans may love the hard r, but lots of people will pass. ant-man was fun, quirky, enjoyable. not this."'],
#  ['634457486079184897',
#   'ant-man',
#   'positive',
#   '" na if they know wa good for them it will be like ant-man, mar-vell would give carol danvers the mantle"'],
#  ['625689955587633154',
#   'ant-man',
#   'positive',
#   '" yeah, on friday i went and saw two movies people bitch about - ant-man and minions. i had a good time! hatersgonnahate"'],
#  ['626537598996099072',
#   'ant-man',
#   'positive',
#   '" fair enough. unrelated, think i may go see ant-man again tomorrow if you\'re interested."'],
#  ['628742656143794176',
#   'ant-man',
#   'positive',
#   '" i\'m gonna see ant-man tomorrow, can\'t wait. (you seeeee, i\'m doing theaters lol)"'],
#  ['629614377860222978',
#   'ant-man',
#   'positive',
#   '" it\'s horrible, complete fail compared to the 1st movie. rather watch ant-man or entourage."'],
#  ['626154598739410944',
#   'ant-man',
#   'positive',
#   '" hoping to see ant-man tomorrow night at the everyman in reigate... apparently it\'s been refurbished and is pretty good,"'],
#  ['628985936559403008',
#   'ant-man',
#   'positive',
#   ' you and me both. was chatting to about 4th wall breaking after ant-man'],
#  ['625143211992969216',
#   'ant-man',
#   'positive',
#   ' do you want to see ant-man on tues?'],
#  ['625698179992915968',
#   'ant-man',
#   'positive',
#   ' my whole family is going to see ant-man on friday before they leave though'],
#  ['632095713258799104',
#   'ant-man',
#   'positive',
#   ' love winter soldier. incredibly close 3rd cause of its ramifications on the mcu. but i had too much fun with ant-man.'],
#  ['629374433338200064',
#   'ant-man',
#   'positive',
#   '" i finally saw ant-man on tuesday i really enjoyed it, the movie was so good &amp; entertaining &amp; i enjoyed the spider-man reference"'],
#  ['628406380161048576',
#   'ant-man',
#   'positive',
#   '" then again, this is coming from the girl who just saw ant-man for the 3rd time"'],
#  ['632097132741283840',
#   'ant-man',
#   'positive',
#   ' may still be out there (avengers). am looking forward to ant-man and heard it si totally awesome!'],
#  ['631834653855481856',
#   'ant-man',
#   'positive',
#   '" i understand, you enjoy ant-man and assure you it will start on time when you return tomorrow"'],
#  ['625730289352986628',
#   'ant-man',
#   'positive',
#   '" i\'m a dumb, the missus booked a sofa at the electric tomorrow for ant-man. fancy it tomorrow?"'],
#  ['628702317743898624',
#   'ant-man',
#   'positive',
#   'a special tuesday night movie with nephew today. we went to see ant-man. it was much better than i had anticipated. a nice old school vibe.'],
#  ['637143363364458500',
#   'ant-man',
#   'positive',
#   "also good news i'm going to go see ant-man tomorrow /twerktwerk"],
#  ['626360335457472512',
#   'ant-man',
#   'positive',
#   'ant-man: screening: sat &amp; sun 1.00pm super tue 6.00pm armed with the astonishing ability... <url>'],
#  ['626504589441953792',
#   'ant-man',
#   'positive',
#   '"also tomorrow on <url> you\'ll find my review of ant-man. that\'s right bitches, i actually saw a new film at the cinema!"'],
#  ['627944172335398912',
#   'ant-man',
#   'positive',
#   "ant-man at amc cinema suites on a sunday afternoon is a great choice. good film. have to see it again cause missed 's scene"],
#  ['625225536969707520',
#   'ant-man',
#   'positive',
#   '"ant-man feels like a rough 1st draft of the marvel universe (namely iron man) which it probably was, considering it\'s where it all started."'],
#  ['628721385628565504',
#   'ant-man',
#   'positive',
#   '"ant-man felt like the 1st ironman movie 2 me. that\'s good. it did feel like 2 films grafted onto each other. not as good, but not bad either"'],
#  ['626392505903411200',
#   'ant-man',
#   'positive',
#   'ant-man is here through the 30th!! antman summer <url>'],
#  ['638542124561137664',
#   'ant-man',
#   'positive',
#   '"ant-man is important. no matter how small his role in civil war may actually be, he is still there for a reason. don\'t downplay him."'],
#  ['626112561264525312',
#   'ant-man',
#   'positive',
#   "ant-man is one of the funniest marvel movies we've watched. check out our spoiler free review! <url> <url>"],
#  ['625458727215308800',
#   'ant-man',
#   'positive',
#   '"ant-man may have cliched and formulaic structure, but it\'s a whole lot of fun. the final 40 mins is superb."'],
#  ['625958378712403968',
#   'ant-man',
#   'positive',
#   '"ant-man premieres tomorrow night in doha. a savior from the atrocity that was ""pixels."""'],
#  ['630859178840489984',
#   'ant-man',
#   'positive',
#   'ant-man review coming tomorrow hope to see you all their! fandomreviews youtube'],
#  ['632258739144294400',
#   'ant-man',
#   'positive',
#   '"ant-man starts tonight! pg-13. showtimes 7pm each night, 4 &amp; 7 weekends. monday matinee, august 17th., - fried... <url>"'],
#  ['634869958669791232',
#   'ant-man',
#   'positive',
#   'ant-man starts tonight! runs fri-mon at 8:00pm nightly &amp; is rated pg. see you at the movies :) <url>'],
#  ['625682675391553540',
#   'ant-man',
#   'positive',
#   'ant-man takes a second week at the top of the box office: while it may not be setting th... <url> via '],
#  ['629538128529895424',
#   'ant-man',
#   'positive',
#   'ant-man tomorrow hopefully and i kind of want to give fantastic four a shot also .'],
#  ['626364990182723585',
#   'ant-man',
#   'positive',
#   '"ant-man tomorrow. looking forward to it, but some asshole ruined it for me."'],
#  ['625414288635772928',
#   'ant-man',
#   'positive',
#   '"ant-man was brilliant. inside out was spectacular. what a great year for movies so far. loved today, just sat in the cinema!"'],
#  ['630108390933397505',
#   'ant-man',
#   'positive',
#   'ant-man was even better the 2nd time'],
#  ['631998508061425665',
#   'ant-man',
#   'positive',
#   '"ant-man was high on my list to see, but didn\'t get the chance until tues night. it was such a fun movie! ant-man v falcon...classic!"'],
#  ['626566204094812164',
#   'ant-man',
#   'positive',
#   '"ant-man was ok. loved the action, first hour dull, 2nd hour great, villain was actually a good villain."'],
#  ['626930362128691204',
#   'ant-man',
#   'positive',
#   'ant-man was ok. nothing amazing but marvel evil for having me sit through the longest credits to see the 2nd end credit scene.'],
#  ['625415211642671104',
#   'ant-man',
#   'positive',
#   '"ant-man, edge of tomorrow, inside out, inglourious basterds and obvious child (my favourite of the week) myweekinmovies"'],
#  ['627226685616881664',
#   'ant-man',
#   'positive',
#   '"ant-man is getting good reviews, might have to go watch it sunday night"'],
#  ['625586775101014016',
#   'ant-man',
#   'positive',
#   '"ant-man tops north american box office: marvel action flick ""ant-man"" stayed atop the us box office sunday, ... <url>"'],
#  ['625582957852397568',
#   'ant-man',
#   'positive',
#   '"ant-man was good tho. and props to the guy who mention about the 2nd extra scene at the end of the movie, you da real mvp."'],
#  ['630299839528615936',
#   'ant-man',
#   'positive',
#   'anybody want to see ant-man tomorrow?'],
#  ['627130938640629761',
#   'ant-man',
#   'positive',
#   '"anyway, i\'m going to the theaters tomorrow to watch ant-man! i\'m really excited. ;o;)b"'],
#  ['632772733550612480',
#   'ant-man',
#   'positive',
#   'back from ant-man for the 2nd time! love that film.'],
#  ['627915905691963392',
#   'ant-man',
#   'positive',
#   '"back to work tomorrow so off to the cinema to finally watch ant-man with jackson. heard good things, plus it\'s marvel... it\'s gonna be mega!"'],
#  ['640221004405559296',
#   'ant-man',
#   'positive',
#   '"been a little busy lately, just now getting to see ant-man. oh and i\'m a child! west 21st st. warren <url>"'],
#  ['630364503864164352',
#   'ant-man',
#   'positive',
#   '"been an ant based week, first seeing ant-man at the cinema. now visiting antwerp. maybe i\'ll finish with meeting ant &amp; dec? hopeful"'],
#  ['625582788616425472',
#   'ant-man',
#   'positive',
#   "best part of ant-man is how hank pym's treasured photo of his wife covers up her actual face with a large sun hat."],
#  ['630632939697643520',
#   'ant-man',
#   'positive',
#   'box office: ant-man avoids a trainwreck with $22.6 million friday for no. 1 ... - hitfix <url>'],
#  ['625334532858900480',
#   'ant-man',
#   'positive',
#   '"breakingnews: \'ant-man\' wins box office for 2nd weekend with $24.8 million haul, edging out \'pixels\' - usatoday <url>"'],
#  ['628675431311540225',
#   'ant-man',
#   'positive',
#   '"cannot wait to see ant-man and southpaw with tomorrow! i need this downtime, badly!"'],
#  ['625432196095078400',
#   'ant-man',
#   'positive',
#   'catching up on films tomorrow with 2nd watch of ant-man in 3d. then 1st watch of maggie and southpaw.southpaw films <url>'],
#  ['630100950422847488',
#   'ant-man',
#   'positive',
#   '"catching up on movies before they leave theaters. trainwreck was as good as everyone says it is. tomorrow, ant-man."'],
#  ['625337471845335040',
#   'ant-man',
#   'positive',
#   'congrats to disney for managing to keep ant-man as the 1 movie for a 2nd weekend with a paltry $24.7 million take. boxoffice'],
#  ['632619893351936000',
#   'ant-man',
#   'positive',
#   'continuing to bond with the offspring via marvel movies with another superhero saturday thanks to a very funny ant-man. fb'],
#  ['631375825519177728',
#   'ant-man',
#   'positive',
#   '"don\'t forget all films before 5pm are just a fiver for all! valid mon - fri only. book now and enjoy ant-man,... <url>"'],
#  ['629715296748634113',
#   'ant-man',
#   'positive',
#   "dragon ball z tomorrow but i don't know if i want to wake up early to see it at 12 ... when i can see f4ntastic or ant-man at a later time"],
#  ['626560152540454912',
#   'ant-man',
#   'positive',
#   '"ends this thursday. have you seen marvel\'s ""ant-man"" yet? <url>"'],
#  ['633396070727356416',
#   'ant-man',
#   'positive',
#   'episode 39: ant-man the comics is out now to hold you over until episode 40 arrives on wednesday! <url>'],
#  ['626032845203464192',
#   'ant-man',
#   'positive',
#   '"fyi, the inspiration 4 ant-man has been turned into a miniseries by and it\'s out tomorrow, theshrinkingman, themoreyouknow"'],
#  ['637257640754679808',
#   'ant-man',
#   'positive',
#   "fantastic four tomorrow will it be as good as ant-man we'll have to see"],
#  ['628241574699397121',
#   'ant-man',
#   'positive',
#   'final shows for pixels &amp; ant-man are thursday! opening wednesday: shaun the sheep &amp; thursday: fantastic four!'],
#  ['627219982540242944',
#   'ant-man',
#   'positive',
#   '"finally going to see ant-man tonight, then off to see rogue nation either tomorrow or sunday. looking forward to both."'],
#  ['635760227497984000',
#   'ant-man',
#   'positive',
#   'finally going to watch ant-man tomorrow its still getting good ratings excited'],
#  ['632820878670041088',
#   'ant-man',
#   'positive',
#   'finally got around to see ant-man and absolutely loved it. nice way to cap off an eventful saturday.'],
#  ['626533602226876416',
#   'ant-man',
#   'positive',
#   '"get paid on friday and all i can think about wanting to do is go to the cinema to watch ant-man, too many good looking films coming out"'],
#  ['630516517403123712',
#   'ant-man',
#   'positive',
#   'going to fantasticfour tomorrow. half expecting the box office girl to give me a sad look and say i can see ant-man a second time instead.'],
#  ['625685345368154112',
#   'ant-man',
#   'positive',
#   'going to go see ant-man on monday morning. i have the best life.'],
#  ['627228610882048001',
#   'ant-man',
#   'positive',
#   "going to go see ant-man tomorrow hope it's good"],
#  ['627890310362718208',
#   'ant-man',
#   'positive',
#   '"going to see ant-man today for the sunday matinee, just need to put the roast beef in the crockpot and i\'m good to go! :d"'],
#  ['625548653596282880',
#   'ant-man',
#   'positive',
#   '"going to the movies tomorrow to watch southpaw, paper towns, train wreck and then ant-man again."'],
#  ['629322310315606016',
#   'ant-man',
#   'positive',
#   '"gonna go to the city this weekend (saturday most likely), shop a bit and watch ant-man, cause hell, i wanna see it!"'],
#  ['630190344882257920',
#   'ant-man',
#   'positive',
#   'gonna wait until tomorrow to see ant-man and take my ma with me.'],
#  ['625671718208671744',
#   'ant-man',
#   'positive',
#   'got to love these three dedicated days of laziness. back to gyming it up tomorrow. before ant-man.'],
#  ['637774002400833536',
#   'ant-man',
#   'positive',
#   'great to see sun girl in last days of ant-man. be great if she survived secret wars! do the right thing =) <url>'],
#  ['627905916143169536',
#   'ant-man',
#   'positive',
#   '"heroes! well, almost. these four lucky residents scored gigs in \'ant-man.\' check out the story tomorrow! <url>"'],
#  ['636828154393300992',
#   'ant-man',
#   'positive',
#   '"had a slightly intoxicated conversation about daredevil, ant-man, civil war, &amp; the mcu. if that\'s not a successful wednesday, then what is?"'],
#  ['630480966713274368',
#   'ant-man',
#   'positive',
#   'had the chance to finally see both the fantastic four and ant-man. if i may indulge in a pun... big things do come from small packages.'],
#  ['626421206451912704',
#   'ant-man',
#   'positive',
#   '"he\'s a handsome devil, isn\'t he? catch him in ant-man, screening for the last time tomorrow! <url> <url>"'],
#  ['625378017657749504',
#   'ant-man',
#   'positive',
#   'hey students! do you like movies? then join us tomorrow at cinemark 6 at 12:30 pm for ant-man! the movie starts at 12:50 pm. see you then!'],
#  ['626855208086319106',
#   'ant-man',
#   'positive',
#   'hi how the editing of your new video coming along? up tomorrow ? waiting to watch it. ant-man opens here tomorrow'],
#  ['636326890488225792',
#   'ant-man',
#   'positive',
#   '"i *could* see ant-man today, or, i could see the live action attack on titan movie in theatres tomorrow...."'],
#  ['640639686625619968',
#   'ant-man',
#   'positive',
#   'i debate seeing ant-man tonight for the 3rd time...do i?'],
#  ['626135805598285825',
#   'ant-man',
#   'positive',
#   '"i don\'t know what i\'m more excited about - starting a new hub8 project, seeing ant-man or charlie coming home from greece tomorrow..."'],
#  ['630964314409558016',
#   'ant-man',
#   'positive',
#   'i finished first at timeplay when i saw ant-man tonight. i think i may have peaked. antman dreambig'],
#  ['629166655621328896',
#   'ant-man',
#   'positive',
#   '"i got 3 options on friday suck it up and watch fantastic four watch ant-man, again or watch mission impossible:rogue mation"'],
#  ['626713612757807104',
#   'ant-man',
#   'positive',
#   '"i had a really great time watching ant-man, reminded me of the 1st time watching iron man , where the character tries to learn who he is"'],
#  ['632662555085942784',
#   'ant-man',
#   'positive',
#   '"i had this written at like half 6 today and almost forgot to post it! <url> featuring wilco, ant-man, whas and more."'],
#  ['635598295230992384',
#   'ant-man',
#   'positive',
#   'i have my agent carter t shirt and my jan earrings. the concession stand guy said stay till the end. as prepared for ant-man as i can be?'],
#  ['638134829171630081',
#   'ant-man',
#   'positive',
#   '"i may be late to this party, but ant-man is a great movie! ranks among my top picks in the marvel cinematic universe, i didn\'t expect that"'],
#  ['633024975297974272',
#   'ant-man',
#   'positive',
#   'i need to get up early tomorrow and finally see ant-man. my local cinema only has one showing and it is just after 12pm.'],
#  ['629773215036895232',
#   'ant-man',
#   'positive',
#   'i plan to see the fantastic 4 movie tuesday. i went to see age of ultron and ant-man the thursday night before.'],
#  ['632948718162051072',
#   'ant-man',
#   'positive',
#   '"i saw ant-man on friday night, but peeked in the showing of soc to see the response. packed showing with racial mix. <url>"'],
#  ['637449297177497602',
#   'ant-man',
#   'positive',
#   'i should go watch ant-man tomorrow because i really want to watch it and have yet to see it.'],
#  ['625859501875294208',
#   'ant-man',
#   'positive',
#   'i think the best stan lee cameo may be in ant-man. it had me laughing hard.'],
#  ['634805705896239104',
#   'ant-man',
#   'positive',
#   'i want to trade an ant-man fig for this yellowjacket. all from june box. tweet if interested <url>'],
#  ['626525700456120320',
#   'ant-man',
#   'positive',
#   'i watched ant-man for the 3rd time today.'],
#  ['627617932390993920',
#   'ant-man',
#   'positive',
#   '"i would say, ant-man is probably my favorite movie of the year so far with mi: rogue nation at a very close 2nd"'],
#  ['625828619265273857',
#   'ant-man',
#   'positive',
#   "i'll end the streak of bad movies tomorrow when i go to ant-man again"],
#  ['625963957665288192',
#   'ant-man',
#   'positive',
#   '"i\'m desperate enough to go see ant-man, but it won\'t be out until august 12 here."'],
#  ['633951124509343745',
#   'ant-man',
#   'positive',
#   '"i\'m going to see ant-man. wednesday, 19 august 2015 at 14:00 in newport - spytty park <url> cineworld"'],
#  ['625860233391288321',
#   'ant-man',
#   'positive',
#   "i've decided to record the new comically on the history of ant-man a day early...i may even have it ready for release tomorrow."],
#  ['625836101454925824',
#   'ant-man',
#   'positive',
#   '"if i can finish this final tonight, i\'ll be able to finally see ant-man tomorrow after work."'],
#  ['630052075213357056',
#   'ant-man',
#   'positive',
#   "if i feel up to going to mum's eye check up may try and see ant-man"],
#  ['628973293895335936',
#   'ant-man',
#   'positive',
#   "if you liked ant-man you may enjoy law and the multiverse's discussion of the whole robbery/burglary distinction. <url>"],
#  ['628340792839548928',
#   'ant-man',
#   'positive',
#   '"if you\'re having doubts about ant-man, just go and see it, you won\'t be disappointed. he may not be a major character, but the movie is good"'],
#  ['625201107120312320',
#   'ant-man',
#   'positive',
#   'ima just go catch a matinee of ant-man by myself tomorrow lol'],
#  ['629325594950549506',
#   'ant-man',
#   'positive',
#   'in other news i saw ant-man! it may have a few flaws but i absolutely loved it! so funny and the character is brilliant'],
#  ['629161464629080064',
#   'ant-man',
#   'positive',
#   '"in other news, can\'t wait to see ant-man tomorrow night, hopefully it\'s what i expect"'],
#  ['625344396284833792',
#   'ant-man',
#   'positive',
#   "isn't that what a bruce jenner nephews call him? ant-man wins box office for 2nd weekend with $24.8m <url>"],
#  ['640406396786339840',
#   'ant-man',
#   'positive',
#   'it seems the rest of my life may just be convincing people to watch ant-man with me.'],
#  ['625253941161381888',
#   'ant-man',
#   'positive',
#   '"it\'s another sunday with perfect cinema weather, so head down for inside out and ant-man worthing book at <url>"'],
#  ['626479889177296898',
#   'ant-man',
#   'positive',
#   '"it\'s official: finally get to go see ant-man tomorrow!! first real day off in 2 months!! so stoked- no spoilers, marvel nation!!"'],
#  ['627590262160773121',
#   'ant-man',
#   'positive',
#   "it's the first of august and started off good with ant-man."],
#  ['625989252619325440',
#   'ant-man',
#   'positive',
#   "just found myself googling 'ant man quantum realm reflection'. i may be thinking about ant-man too much. it is ace though."],
#  ['639970071712890882',
#   'ant-man',
#   'positive',
#   "just saw ant-man in the theatre for the 3rd time. it's still super great."],
#  ['626832697302757376',
#   'ant-man',
#   'positive',
#   "last day for ant-man! mission impossible rogue nation opens fri! i am so impressed with this movie! don't miss it! <url>"],
#  ['625401300218327040',
#   'ant-man',
#   'positive',
#   '"looks like ant-man is gonna hit 1 for the 2nd straight weekend. not to mention, also pass the $100 million mark. not too shabby........"'],
#  ['629981670876311552',
#   'ant-man',
#   'positive',
#   "m:i 5 was... ok. nowhere near as awesome the 4th was. glad i didn't spend $11 at the theater for it. i would rather watch ant-man again."],
#  ['626347530142396417',
#   'ant-man',
#   'positive',
#   'many blessings lately: &amp;nbsp;&amp;nbsp;&amp;nbsp;&amp;nbsp;&amp;nbsp;got out to the theater last saturday to see ant-man . not only <url>'],
#  ['632609747686981632',
#   'ant-man',
#   'positive',
#   '"marvel kicks off the presentation! alan horn starts by praising ant-man\'s 1 opening, which he says is marvel\'s 12th consecutive 1 opener."'],
#  ['640650632525844480',
#   'ant-man',
#   'positive',
#   'may go see ant-man tonight. anyone interested?'],
#  ['625308278327799808',
#   'ant-man',
#   'positive',
#   "maybe on monday i'm going to see ant-man with the squad"],
#  ['626578472958316544',
#   'ant-man',
#   'positive',
#   'michael douglas may not be coming back for another marvel film...he did so good in ant-man though'],
#  ['627415534120775681',
#   'ant-man',
#   'positive',
#   'might just have to go see ant-man tomorrow'],
#  ['625870587324428288',
#   'ant-man',
#   'positive',
#   '"my cousin snapchatted me ""ant-man tomorrow. you good?"" and these are the reasons we get along so well."'],
#  ['633766172870230016',
#   'ant-man',
#   'positive',
#   'my dad and sister will try out daredevil series tomorrow. they really liked ant-man when i recommended it to them... hehehehehe!'],
#  ['630559375392903168',
#   'ant-man',
#   'positive',
#   "my plan for tomorrow's surprise day off is to finally see ant-man."],
#  ['626433405220225024',
#   'ant-man',
#   'positive',
#   '"no work for the rest of the week means ant-man tomorrow morning, followed by a trip to the comic shop, and much lazing about."'],
#  ['625442405358153728',
#   'ant-man',
#   'positive',
#   '"nothing like finishing the last day back to work with friday\'s, and ant-man."'],
#  ['627950169275924480',
#   'ant-man',
#   'positive',
#   'now going to watch ant-man for a 2nd time and drving everybody...'],
#  ['629919057114853376',
#   'ant-man',
#   'positive',
#   '"now that there\'s several 2d showings of ant-man a day, maybe i\'ll actually see it... like tomorrow."'],
#  ['626457697643331585',
#   'ant-man',
#   'positive',
#   '"ohhhhh, do i see mi:5 or ant-man on friday at the cinema... hmmmm."'],
#  ['625729349589803008',
#   'ant-man',
#   'positive',
#   '"okay, i forgive the makers of ant-man for omitting jan pym. it\'s a funny, exciting, heist film with a lot of honor to dads. go see it."'],
#  ['626975801074929664',
#   'ant-man',
#   'positive',
#   "or tomorrow i don't care but i want to watch ant-man"],
#  ['627530541781372928',
#   'ant-man',
#   'positive',
#   '"paid my bills, bought some groceries, did a bit of price-shopping on some clothes, and bought my ticket for ant-man later tonight. saturday"'],
#  ['637383571116703744',
#   'ant-man',
#   'positive',
#   '"paul rudd stars as ant-man, showing tonight, tomorrow and sunday. rated pg-13. showtimes are at 7:15 each night.... <url>"'],
#  ['626801802571177984',
#   'ant-man',
#   'positive',
#   "planning to watch ant-man tomorrow and see all the fuss about .... i hope i won't get disappointed ....."],
#  ['633184120902778880',
#   'ant-man',
#   'positive',
#   'probably why marvel is waiting to show the civil war trailer until late sep/early oct to give ppl enough time to get caught up w/ ant-man'],
#  ['625335403789307904',
#   'ant-man',
#   'positive',
#   'question... is ant-man any good? tempted to go watch it tomorrow'],
#  ['637775424483934208',
#   'ant-man',
#   'positive',
#   '"recording a new fanboy versus tomorrow with and talking fantastic four, ant-man and more!"'],
#  ['627286836503801856',
#   'ant-man',
#   'positive',
#   '"snap!: ant-man even with this being my 2nd time seeing it, ant-man still blew me away. best solo marvel film yet. truth"'],
#  ['627364150952493056',
#   'ant-man',
#   'positive',
#   '"saturday movie reviews: ""ant-man"" is fun &amp; light <url> while ""woman in gold"" is tugs at the heart <url>"'],
#  ['625540747970744320',
#   'ant-man',
#   'positive',
#   '"saw ant-man last sunday, and finally had time to draw it today. <url> <url>"'],
#  ['629220123300204544',
#   'ant-man',
#   'positive',
#   'saw ant-man on tuesday. great film. much more character driven than the big epic mcu films.'],
#  ['628311572650303488',
#   'ant-man',
#   'positive',
#   "saw ant-man tonight and loved it! here's my blog review: <url> any views appreciated! antman marvel"],
#  ['625511182552530944',
#   'ant-man',
#   'positive',
#   'saw ant-man tonight with friends. my 3rd time. fun.'],
#  ['627026886137376768',
#   'ant-man',
#   'positive',
#   '"seeing ant-man on monday, finally. 9pm showing, so i\'ll be useless the next day. and i don\'t care."'],
#  ['629826086289965056',
#   'ant-man',
#   'positive',
#   '"seeing ant-man tomorrow, flat, it just isn\'t worth $40 *more* to see it in 3d. we\'ll just have to use our imaginations."'],
#  ['627296698436612098',
#   'ant-man',
#   'positive',
#   '"seeing ant-man for the 2nd time ( amc north point mall 12 - amctheatres for ant-man in alpharetta, ga) <url>"'],
#  ['630522497709043712',
#   'ant-man',
#   'positive',
#   'shoutout to for going with me to see ant-man (highly recommend) and scoring us free ice cream yesterday. best 2nd to last day here'],
#  ['625918623391969280',
#   'ant-man',
#   'positive',
#   '"so.. finally saw in ant-man, i thin i may have zoned out starin at her tho cuz i remember nothing the guy said except ""yes"""'],
#  ['629870864436207616',
#   'ant-man',
#   'positive',
#   "somehow i was able to enjoy the 2nd half of ant-man in spite of my gleeful anticipation about all the ant-lamb jokes i couldn't wait to make"],
#  ['625303987810643968',
#   'ant-man',
#   'positive',
#   '"somehow got wrangled into seeing ant-man again tomorrow with another group of friends. ehh, i don\'t mind much tbh"'],
#  ['625490558564343808',
#   'ant-man',
#   'positive',
#   "star&gt;box office:ant-man stomps on the competition for 2nd weekend at 1:marvel studios' ant-man was 1 at t... <url> actors"],
#  ['626392982766419968',
#   'ant-man',
#   'positive',
#   '"still really want to see ant-man, hopefully tonight or tomorrow."'],
#  ['628012999861637120',
#   'ant-man',
#   'positive',
#   'summer is busy! saw ant-man with super heroes lilf and . tomorrow minecraft with and '],
#  ['627909802224709633',
#   'ant-man',
#   'positive',
#   '"sunday recovery continues with this, then ant-man <url>"'],
#  ['625166792940503040',
#   'ant-man',
#   'positive',
#   '"sure, ant-man is a cool film, but make sure you know all your movie options. ... (vine by saturday night vine) <url>"'],
#  ['625148530517082112',
#   'ant-man',
#   'positive',
#   '"swapped out broken franken-part in my car, saw ant-man with family, took a nap, wrote for a bit, ate ice cream. saturday: victorious."'],
#  ['630144580109910016',
#   'ant-man',
#   'positive',
#   'tfw ur on ur way to see ant-man for the 3rd time'],
#  ['625699761337700354',
#   'ant-man',
#   'positive',
#   '"the top 5 marvel cinematic universe films of phase 1 and phase 2: with the release of ant-man, phase 2 of mar... <url>"'],
#  ['627167554750918657',
#   'ant-man',
#   'positive',
#   "the best cgi in ant-man isn't the ant scenes. it's that 1st scene with michael douglas' face. smhowzow"],
#  ['641027787026006016',
#   'ant-man',
#   'positive',
#   'there are people who only watched ant-man for the upstate ny cameo and the 2nd credit scene. civil war is going to be pretty big.'],
#  ['630086698182045696',
#   'ant-man',
#   'positive',
#   'thought about seeing the new fantastic four movie today. passed and saw ant-man for a 2nd time instead. lol antman fantasticfour'],
#  ['625733731949649924',
#   'ant-man',
#   'positive',
#   '"tickets to see ant-man with and this friday! looking forward to it, heard such mixed reactions to the film"'],
#  ['625296715860475912',
#   'ant-man',
#   'positive',
#   'tomorrow i wanna have dinner out and watch ant-man. who wants to come with me?'],
#  ['626390098641170432',
#   'ant-man',
#   'positive',
#   '"tomorrow is the last day to see ant-man so mission: impossible rogue nation can begin friday, july 31st. to see... <url>"'],
#  ['628376234586550272',
#   'ant-man',
#   'positive',
#   "took the day off work and treated babe to some big biscuit and saw ant-man. some monday's aren't too bad."],
#  ['625832748901502976',
#   'ant-man',
#   'positive',
#   '"trying to get tickets to the ""ant-man"" preview showings on wednesday. the theaters are fucking packed, bro. i\'m kind of happy...paul rudd!"'],
#  ['627787138004873216',
#   'ant-man',
#   'positive',
#   'unexpected development-- saw ant-man on saturday night in london. it was surprisingly charming. i actually quite enjoyed it.'],
#  ['625441745380200449',
#   'ant-man',
#   'positive',
#   '"very excited to see ant-man tomorrow but after i\'ve seen it, i will have seen all mcu films this yearaka i have to wait 9 months for another"'],
#  ['625763310483427329',
#   'ant-man',
#   'positive',
#   "was gonna see inside out again tomorrow but i found it a bit disappointing so we'll probably watch ant-man again"],
#  ['627737110271782912',
#   'ant-man',
#   'positive',
#   '"watched ant-man for the 2nd time today, and thought of 2 more reasons to see it again: to catch the easter eggs and catalog its britishisms."'],
#  ['625235809621295105',
#   'ant-man',
#   'positive',
#   '"watched ant-man for the 3rd time for free, technically because it\'s with family. :)))"'],
#  ['633608542856040448',
#   'ant-man',
#   'positive',
#   'we hope you are enjoying pixels. ant-man will start this friday. armed with a super-suit with the astonishing... <url>'],
#  ['628152054066872320',
#   'ant-man',
#   'positive',
#   '"we saw ant-man last saturday - it was very good. proves that no matter your size, you are still a super hero! <url>"'],
#  ['625743856680611840',
#   'ant-man',
#   'positive',
#   'we will be highlight our guests every monday for cmx2015 and we are kicking it off with sara moni! with ant-man... <url>'],
#  ['626001974287310849',
#   'ant-man',
#   'positive',
#   '"wednesday is movie day! we recently saw ant-man, southpaw and amy (the amy winehouse documentary). what have... <url>"'],
#  ['627694528808517632',
#   'ant-man',
#   'positive',
#   'what are the chances of ant-man still being in theatres on august 20th when i get to halifax?'],
#  ['627730117175943168',
#   'ant-man',
#   'positive',
#   "who wants to go see ant-man tomorrow? i believe it's a film about a man who's imbued with all the powers of a guy named anthony."],
#  ['625902104578658304',
#   'ant-man',
#   'positive',
#   'who wants to see ant-man with me tomorrow ://'],
#  ['626218570503061505',
#   'ant-man',
#   'positive',
#   '"why it\'s great to go see ant-man in imax (or any movie, really), at the tuesday late night showing. <url>"'],
#  ['625147733410775040',
#   'ant-man',
#   'positive',
#   "will someone go see ant-man with me tomorrow? i'm dying to see it"],
#  ['625144853433856005',
#   'ant-man',
#   'positive',
#   'can it just be 5:30 tomorrow evening already because ant-man will be over by then and the post credits will begin <url>'],
#  ['627886110996197376',
#   'ant-man',
#   'positive',
#   '"going to see ant-man today then will get pasta, i\'m doing all my birthday stuff today because i have band camp tomorrow and that\'s all day"'],
#  ['626916158550073344',
#   'ant-man',
#   'positive',
#   '"it\'s crazy how i swore up &amp; down that ""ant-man"" would stink but i\'m excited to see it a 2nd time."'],
#  ['631371838078218240',
#   'ant-man',
#   'positive',
#   "just booked my tickets for ant-man for this friday. can't wait!"],
#  ['627021404374855680',
#   'ant-man',
#   'positive',
#   'might as well go see ant-man for the 4th time again since its release..'],
#  ['626180174485307392',
#   'ant-man',
#   'positive',
#   '"proper geeking out today; ant-man was so good and under the dome till i sleep, mate im gonna be dead tomorrow"'],
#  ['633112305694146560',
#   'ant-man',
#   'positive',
#   '"seeing ""straight outta compton"" &amp; ""ant-man"" tomorrow is the move.. gotta decide on a 3rd movie as well."'],
#  ['634738519911628800',
#   'ant-man',
#   'positive',
#   'should i force my dad to go to the cinema with me and watch ant-man (that would be my 2nd time watching it) (i missed the post-credit scene)'],
#  ['629682224305016832',
#   'ant-man',
#   'positive',
#   'thinking about the number of people who may have discovered the cure through ant-man makes me so happy'],
#  ['632636515127050240',
#   'ant-man',
#   'positive',
#   'why pack for moving to college tomorrow when you can watch three different trailers for ant-man instead'],
#  ['622298667823726592',
#   'bad blood',
#   'negative',
#   " may i remind you she's kida hot is number one on the itunes chart while bad blood is at number 50 play the more popular one"],
#  ['639305345332973568',
#   'bad blood',
#   'negative',
# ...
#  ['633031762281541632',
#   'brock lesnar',
#   'positive',
#   "ooohh yeah i just remembered... i'm going to raw tomorrow!!!!!!! undertaker and brock lesnar!!!!!!!!! rawminneapolis"],
#  ['636368888293232640',
#   'brock lesnar',
#   'positive',
#   '"rip bo dallas, we hardly knew you. loved this. wwe raw, bo dallas interrupt brock lesnar, aug 24, 2015 <url> via "'],
#  ['624065412917932033',
#   'brock lesnar',
#   'positive',
#   '"replaying wwe july 13. if i was j&amp;j securities, i would never try to mess with brock lesnar. he\'s cool. omg"'],
#  ['623891690760310785',
#   'brock lesnar',
#   'positive',
#   '"save the date, august 23 2015, summerslam main event, the undertaker vs. brock lesnar..gonna be epic..wwe"'],
#  ['635641944366936064',
#   'brock lesnar',
#   'positive',
#   'seeing undertaker laugh at brock lesnar may have been the greatest thing i have ever seen! brockvstaker wwe summerslam'],
#  ['623295431624294400',
#   'brock lesnar',
#   'positive',
#   'so brock lesnar is just going to throw every single person on the roster into the sun? great. raw'],
#  ['624510194144272384',
#   'brock lesnar',
#   'positive',
#   '"ten sports , brock lesnar is win the fight.because he diserved it. ""believe that""raw sunday dhamal"'],
#  ['624379366001111040',
#   'brock lesnar',
#   'positive',
#   'that brawl between undertaker and brock lesnar was crazy last monday on raw i want to see more'],
#  ['623451018907545600',
#   'brock lesnar',
#   'positive',
#   'that scrap between the undertaker and brock lesnar on monday night raw last night looked like the best craic ever'],
#  ['633760001471967232',
#   'brock lesnar',
#   'positive',
#   'that was absolutely the most amazing episode of monday night raw minneapolis all hail brock lesnar!!! brockhomecoming'],
#  ['623298267678416896',
#   'brock lesnar',
#   'positive',
#   '"the undertaker and brock lesnar going at it on monday night raw was unbelievable, another reason why i am fan of professional wrestling."'],
#  ['635646781045518338',
#   'brock lesnar',
#   'positive',
#   'undertaker officially won but we know brock lesnar should be the winner watch raw tomorrow night ! sumerslam wwe <url>'],
#  ['625842042078232576',
#   'brock lesnar',
#   'positive',
#   'undertaker vs brock lesnar may just be interesting summerslam raw'],
#  ['632662000502501376',
#   'brock lesnar',
#   'positive',
#   'undertaker vs brock lesnar kesho sunday wah... this is the fight of the century now .... i need to see the... <url>'],
#  ['634443283758866433',
#   'brock lesnar',
#   'positive',
#   'very excited for summerslam paperview this sunday. man i really hope the undertaker tombstones brock lesnar back to the ufc'],
#  ['633539411431452672',
#   'brock lesnar',
#   'positive',
#   '"wwe in brock lesnar\'s territory of minneapolis, minnesota! and fittingly lesnarvstaker on monday night raw. i love it! summerslam"'],
#  ['623577188898598912',
#   'brock lesnar',
#   'positive',
#   "what chaos between brock lesnar and undertaker on monday night raw loved it can't wait for summerslam <url>"],
#  ['635123696584273920',
#   'brock lesnar',
#   'positive',
#   "wishing sunday was today. summerslam someone's going to hell tomorrow night. either brock lesnar or undertaker."],
#  ['635966102342791169',
#   'brock lesnar',
#   'positive',
#   'woah! what a way to kick off monday night raw with brock lesnar!'],
#  ['628225795283099648',
#   'brock lesnar',
#   'positive',
#   "wwe monday night raw is going to be hilarious i can't wait for this and brock lesnar"],
#  ['633680240565440512',
#   'brock lesnar',
#   'positive',
#   'you already know brock lesnar will beat/win the undertaker this sunday at summer slam looool mark my words'],
#  ['627322144683368448',
#   'brock lesnar',
#   'positive',
#   'you can sell your soul to the devil but your ass belongs to brock lesnar.....may just be the greatest ever to pick up a mic'],
#  ['623302415706628096',
#   'brock lesnar',
#   'positive',
#   '"you can take ufc, mma or heavyweight boxing but that brock lesnar vs undertaker fight on may have been one of the best ever brawls."'],
#  ['625240801925173248',
#   'brock lesnar',
#   'positive',
#   'your soul may belong to the devil but your ass belongs to my client brock lesnar undertaker my fav but that line was classic '],
#  ['628383885567598593',
#   'brock lesnar',
#   'positive',
#   'i guess its good to keep brock lesnar for the 3rd hour keeppeoplewatching raw wwe'],
#  ['624547510682583040',
#   'brock lesnar',
#   'positive',
#   '"joabyxnx: last monday the undertaker took brock lesnar back to kindergarten. yes, i watch wrestling. wwebattleground"'],
#  ['627007453842927616',
#   'brock lesnar',
#   'positive',
#   '"just like the old times.. :d ""brock lesnar confronts the undertaker: raw, july 20, 2015"" <url>"'],
#  ['635444887152820224',
#   'caitlyn jenner',
#   'negative',
#   'caitlyn jenner may face manslaughter charge in malibu crash i read it on video: <url>'],
#  ['634805848217362433',
#   'caitlyn jenner',
#   'negative',
#   '"caitlyn jenner may face manslaughter charges ""good she manslaughtered her penis"" -brandon"'],
#  ['633414773028159488',
#   'caitlyn jenner',
#   'negative',
#   'what if we make a celebrity death match between bruce jenner vs caitlyn jenner??..... officetalk monday hollywood'],
#  ['633817523557920768',
#   'caitlyn jenner',
#   'negative',
#   "describeyourphobia running into caitlyn jenner in the dark... or the light... or in the midday sun... or at all. i'm scared of ghouls"],
#  ['631197882465550337',
#   'caitlyn jenner',
#   'negative',
#   '" i know, me too. this was the kakkest fake monday ever. it could have been worse... it could have had a photo of caitlyn jenner"'],
#  ['636239264045527041',
#   'caitlyn jenner',
#   'negative',
#   ' i rather watch paint dry or stare at the sun. your show is 100% fake like you caitlyn jenner. tsktskshameshame!'],
#  ['637588675707035648',
#   'caitlyn jenner',
#   'negative',
#   " we are teaching kids that it's ok for guys to be in touch with their feminine side...and that caitlyn jenner may be a cow..."],
#  ['634456046124142592',
#   'caitlyn jenner',
#   'negative',
#   "breaking news: caitlyn jenner may face manslaughter charges in fatal car accident.good he ain't above the law.make him pay."],
#  ['634521861808869376',
#   'caitlyn jenner',
#   'negative',
#   "because she's caitlyn jenner. come to fl sistah where you can run someone over with no consequences. <url>"],
#  ['634766131975323648',
#   'caitlyn jenner',
#   'negative',
#   '"bill burr made gross transphobic jokes about caitlyn jenner on conan: on thursday, comedian bill burr appeared... <url>"'],
#  ['634502810294448129',
#   'caitlyn jenner',
#   'negative',
#   '"but hey, caitlyn jenner may be a woman now but she was a rich white man not too long ago. the privilege never went away"'],
#  ['634446064079101953',
#   'caitlyn jenner',
#   'negative',
#   "caitlyn jenner could be charged with vehicular manslaughter. she insists that she's innocent &amp; bruce was the culprit! <url>"],
#  ['634485813145923584',
#   'caitlyn jenner',
#   'negative',
#   'caitlyn jenner fears going to jail more than she did transitioning: caitlyn jenner may be going to jail and th... <url>'],
#  ['641075476287455232',
#   'caitlyn jenner',
#   'negative',
#   'caitlyn jenner sued for manslaughter: caitlyn jenner was the cause of a 4 vehicle car crash on february 7th. r... <url>'],
#  ['631401297950998528',
#   'caitlyn jenner',
#   'negative',
#   '"caitlyn jenner and her ex-wife, kris jenner, have reportedly been feuding over everything under the sun, teamfollower follow ifollowback"'],
#  ['635275520935002113',
#   'caitlyn jenner',
#   'negative',
#   'caitlyn jenner is accused of manslaughter in a crash during the bruce era. police may call it off after trouble locating a bruce jenner.'],
#  ['634605054813581312',
#   'caitlyn jenner',
#   'negative',
#   'caitlyn jenner is being charges for vehicular manslaughter cause someone died in a car accident in february. does she go to male or female'],
#  ['635036287452450817',
#   'caitlyn jenner',
#   'negative',
#   '"caitlyn jenner is distraught about the prospect of going to female prison. bruce jenner, however, is thrilled that his plan may have worked."'],
#  ['634465043950600193',
#   'caitlyn jenner',
#   'negative',
#   'caitlyn jenner may be charged with manslaughter after a fatal malibu car crash <url>'],
#  ['634508897131339776',
#   'caitlyn jenner',
#   'negative',
#   'caitlyn jenner may be charged with manslaughter for fatal crash: the accident occurred whe... <url> cadillac escalade'],
#  ['634499978900189184',
#   'caitlyn jenner',
#   'negative',
#   "caitlyn jenner may be charged with manslaughter. but bruce jenner was driving. doesn't that lead to a defense of mistaken sexual identity?"],
#  ['638899971698241537',
#   'caitlyn jenner',
#   'negative',
#   '"caitlyn jenner may be charged with manslaughter: when you are involved in a motor vehicle accident, you suffer... <url>"'],
#  ['634463428594241536',
#   'caitlyn jenner',
#   'negative',
#   "caitlyn jenner may be charged with vehicular manslaughter guess women really can't drive"],
#  ['634475659570450432',
#   'caitlyn jenner',
#   'negative',
#   'caitlyn jenner may be facing manslaughter charges n not cuz she cut off her junk!!! :d couldnthelpmyself'],
#  ['634811958563225600',
#   'caitlyn jenner',
#   'negative',
#   'caitlyn jenner may be going to jail for killing that chick: caitlyn jenner leaving the nice guy nightclub in w... <url>'],
#  ['634460568250748928',
#   'caitlyn jenner',
#   'negative',
#   'caitlyn jenner may be responsible for the death of jon benet ramsey (and someone else) <url> via lgbt'],
#  ['634500678698799104',
#   'caitlyn jenner',
#   'negative',
#   "caitlyn jenner may be serving jail time? what's the bad news?"],
#  ['635165416227127296',
#   'caitlyn jenner',
#   'negative',
#   'caitlyn jenner may face manslaughter charge in deadly crash <url> via good! so selfish not above the law jail!'],
#  ['634496484336095233',
#   'caitlyn jenner',
#   'negative',
#   "caitlyn jenner may face manslaughter charge?! i guess i don't get it. i mean sure her transition was intentional but bruce is still alive..."],
#  ['634489726318325766',
#   'caitlyn jenner',
#   'negative',
#   'caitlyn jenner may face manslaughter charges for her involvement in a car accident. oh the irony.'],
#  ['634472640510492672',
#   'caitlyn jenner',
#   'negative',
#   'caitlyn jenner may face manslaughter charges in fatal car accident: prosecutors have recommended the tv star f... <url>'],
#  ['634495820822388737',
#   'caitlyn jenner',
#   'negative',
#   '"caitlyn jenner may face manslaughter charges in fatal crash, or as she called it, womanslaughter. "'],
#  ['634472266642788354',
#   'caitlyn jenner',
#   'negative',
#   '"caitlyn jenner may face manslaughter charges, but on the bright side, her new vagina could still be tried as an adolescent."'],
#  ['634476499731632130',
#   'caitlyn jenner',
#   'negative',
#   '"caitlyn jenner may face manslaughter charges, good get that experiment out of here i\'m sick of looking at it"'],
#  ['636600371729838080',
#   'caitlyn jenner',
#   'negative',
#   "caitlyn jenner may face vehicular manslaughter charges. only three months as a woman and already she can't fucking drive."],
#  ['634499487931736064',
#   'caitlyn jenner',
#   'negative',
#   'caitlyn jenner may have killed someone with her car but in her defense there was a problem with the tranny'],
#  ['639954535734247424',
#   'caitlyn jenner',
#   'negative',
#   '"caitlyn jenner may not be ""down"" with gay marriage, but she should really understand that people are gonna see that as hypocritical."'],
#  ['637549681527033857',
#   'caitlyn jenner',
#   'negative',
#   '"caitlyn jenner might get sued for $18.5m in malibu incident: washington d.c., aug 29 : adding to the caitlyn j... <url>"'],
#  ['641647562227777536',
#   'caitlyn jenner',
#   'negative',
#   '"caitlyn jenner opens up on feb. 2015 accident, fears she may be forced into men\'s jail for manslaughter <url>"'],
#  ['634729754667655168',
#   'caitlyn jenner',
#   'negative',
#   '"caitlyn jenner\'s car accident that killed someone was back in february, so i believe she was still big brucey at that point"'],
#  ['634470669279993856',
#   'caitlyn jenner',
#   'negative',
#   'dj derrty d sports caitlyn jenner may be charged with manslaughter in february crash <url>'],
#  ['634553119771336704',
#   'caitlyn jenner',
#   'negative',
#   '"heard on news: ""caitlyn jenner may be charged with manslaughter. experts say her gender won\'t have any effect on charges"" seriously? smdh"'],
#  ['631878755519217664',
#   'caitlyn jenner',
#   'negative',
#   '"i can\'t wait to watch it this august"": everything about caitlyn jenner irritates me.. when i see the ad of her reality tv show.."'],
#  ['634779173249228801',
#   'caitlyn jenner',
#   'negative',
#   '"i don\'t care what you say. ""caitlyn jenner may be charged with manslaughter."" makes me laugh every time i read it."'],
#  ['640353203607900160',
#   'caitlyn jenner',
#   'negative',
#   'i hear that caitlyn jenner may have to go to jail. i guess she committed manslaughter! <url>'],
#  ['641333912371863553',
#   'caitlyn jenner',
#   'negative',
#   "i may talk my shit about caitlyn jenner. but i'm going to use her correct name and pronouns. that's the least i can do."],
#  ['630129589432352768',
#   'caitlyn jenner',
#   'negative',
#   '"i sat down two men today and all they could talk about was how nasty caitlyn jenner, i found their sexuality even more disgusting than hers"'],
#  ['636321389688000512',
#   'caitlyn jenner',
#   'negative',
#   '"i think making caitlyn jenner into a halloween costume may be the definition of ""too soon."" <url>"'],
#  ['634503451217666049',
#   'caitlyn jenner',
#   'negative',
#   '"in case you were wondering, caitlyn jenner is responsible for the death of a woman in a car crash in february. how courageous is she now?"'],
#  ['634448019337912320',
#   'caitlyn jenner',
#   'negative',
#   "in case you're still calling caitlyn jenner a hero. <url>"],
#  ['634867223300046848',
#   'caitlyn jenner',
#   'negative',
#   "it's looking possible that caitlyn jenner may be charged with manslaughter. serious question: does she go to a male or female prison??"],
#  ['635286078098771968',
#   'caitlyn jenner',
#   'negative',
#   'just heard that caitlyn jenner may be charged with manslaughter after being involved in a fata... <url> via '],
#  ['635886690075328513',
#   'caitlyn jenner',
#   'negative',
#   'just watched the caitlyn jenner shit for the 1st time... ummmm he still sound just like bruce. never watching again'],
#  ['634494291423940608',
#   'caitlyn jenner',
#   'negative',
#   '"me ""caitlyn jenner may get charged for manslaughter."" ""at least it\'s not women slaughter"""'],
#  ['636344138326216705',
#   'caitlyn jenner',
#   'negative',
#   'prosecutors began reviewing evidence on tuesday in the fatal crash involving caitlyn jenner: <url>'],
#  ['630947328300552192',
#   'caitlyn jenner',
#   'negative',
#   '"regardless of how ""courageous"" caitlyn jenner may be he still makes an ugly ass women lol"'],
#  ['632581583979986945',
#   'caitlyn jenner',
#   'negative',
#   '"she may be trans, but she has 100 million to wipe away her tears from being discriminated against. i feel no sympathy for caitlyn jenner."'],
#  ['634510435941785601',
#   'caitlyn jenner',
#   'negative',
#   '"since the crash happened in february, that means that they can\'t charge caitlyn jenner with manslaughter if bruce jenner commited the crash."'],
#  ['634505913131511808',
#   'caitlyn jenner',
#   'negative',
#   'so caitlyn jenner may face man slaughter charges. he thought that the sex change would be easier for when she goes to prison'],
#  ['634523348479967232',
#   'caitlyn jenner',
#   'negative',
#   'so caitlyn jenner may face manslaughter charges. the jokes just write themselves these days... transcriminal'],
#  ['634477308833828864',
#   'caitlyn jenner',
#   'negative',
#   'so caitlyn jenner may face manslaughter charges? ironic she already slaughtered her manhood'],
#  ['636497246389993472',
#   'caitlyn jenner',
#   'negative',
#   "the sun calls reactions to the caitlyn jenner costume a 'fan meltdown': <url> [paywall]"],
#  ['635291585110929408',
#   'caitlyn jenner',
#   'negative',
#   "there's a 50/50 % chance that caitlyn jenner may be charged with manslaughter i should think so as well after what she did to poor bruce"],
#  ...]

# %%
trainTweets = [x[3] for x in trainData]
X_train = np.array(trainTweets)
trainSents = [x[2] for x in trainData]
y_train = np.array(trainSents)
testTweets = [x[3] for x in testData]
X_test = np.array(testTweets)
testSents = [x[2] for x in testData]
# y_test = []
testTweets
# Out:
# [" amy schumer is the stereotypical 1st world laci green feminazi. plus she's unfunny",
#  " i mean i get the hype around jlaw. i may not like her but i get her hype. i just don't understand amy schumer and her hype",
#  'amy schumer at the gqmenoftheyear2015 party in a dress we pretty much hate: <url> gqmoty2015 <url>',
#  "amy schumer is on sky atlantic doing one of the worst stand up sets i have ever seen. and i've almost sat through 30 seconds of millican.",
#  '"amy schumer may have brought us trainwreck, but that word just got redefined on thevoice."',
#  'i just think that sports are stupid &amp;anyone who likes them is a lesser person &amp; has a small intellect- amy schumer <url>',
#  '"if you do like amy schumer, i hope you went &amp; saw her saturday bc after this ridiculousness, i highly doubt maine will be on list of faves."',
#  '"people are like, ""amy schumer? i don\'t like her, she\'s fat."" and i\'m all like ralphie may is fatter, and i don\'t... <url>"',
#  '"seriously though, somebody posted amy schumer as their woman crush wednesday on instagram &amp; i almost went off, but it\'s not worth it"',
#  "they may be mean but i guess they're not stupid...free ted but you have to pay for amy schumer - most unimpressed. <url>",
#  'this amy schumer segment is now old news about 2 days too late...good producer would have had it on monday local24 lml',
#  'warning: this may not safe for work. but mojo &amp; ac just found out about some new amy schumer leaked nudes! <url>',
#  "if i have to read another article about how amy schumer is a feminist icon i'm going to fucking toss myself into the sun",
#  '"snl well it\'s a good thing i stumbled upon maya rudolph, amy schumer, paul mccartney &amp; bruce\'s 3rd after roh10man. cheeseburger kget"',
#  "'amy schumer' appeared on monday 30 at the 13th place in the top20 of los angeles's trends: <url> trndnl",
#  "...1st of all this is amy schumer and she's funnier and hotter than you will ever be 2nd of all shut the fuck up <url>",
#  "41 amy schumer quotes to get you through wednesday (she's pretty badass) <url> <url>",
#  "amy schumer tickets still available for sunday's show at kent state!! go to the <url> website! <url>",
#  'actress and comedian amy schumer shared an intimate portrait on monday that it will not quickly be forgotten.',
#  'amy schumer and jerry seinfeld headline a show in support of the 15th anniversary of baby buggy <url> via ',
#  'amy schumer will be here friday &amp; i want to go!',
#  "amy schumer's honest post may actually inspire you to strip down: <url> <url>",
#  '"and my toughest final is tomorrow, it\'s cumulative, and i\'ve been watching amy schumer and the office all night instead of studying"',
#  "can't wait to see amy schumer with tomorrow!",
#  '"demi lovato praises amy schumer on 2016 pirelli calendar photo: on thursday night, the comedian spoke ... <url> lovato"',
#  "did you know that 'amy schumer' was trending topic on monday 30 for 4 hours in united states? <url> trndnl",
#  '"done with ahs till wednesday &amp; finished inside amy schumer, now what?"',
#  '"for those that wanna see inside amy schumer\'s golden globes , it may happen! cantwait <url>"',
#  '"from my 2nd family, katherine m., a student in nyc, got an internship with amy schumer...now that\'s cool."',
#  "going to see amy schumer in nashville tonight. but don't worry i got your epl plays over on <url>",
#  "i get to see amy schumer live tomorrow. i'm literally the luckiest girl on planet earth",
#  'i just want it to be saturday so amy schumer can make me laugh and feel good about my life compared to hers.',
#  '"i think i may have just fell in love with after watching ""amy schumer: live...extended cut"" on ."',
#  '"i\'m just really excited for my comedy filled day tomorrow... amy schumer live and john mulaney on netflix?! thank you, america."',
#  'inside amy schumer is scorching its merry way back onto in the new year. s3 begins on jan 11 at 11pm. (s2 still on demand.)',
#  'it was a wild night at jazz at the bistro. amy schumer &amp; cast dug our 2nd set &amp; had a comedy jam- epic! <url>',
#  '"kerry washington, viola davis, amy schumer and jill soloway all make power 100 list for 1st time. changingtheworld"',
#  'kind of equally excited at staying in watching the soup finale tonight as i am for going out to see amy schumer tomorrow. well...kind of',
#  'on saturday night live set today with amy schumer! <url>',
#  '"one of the 1st jokes from the hilarious amy schumer at : ""if anybody thought they were seeing \'godspell\' tonight, maybe exit left."""',
#  'outrageously funny: amy schumer plays mohegan sun tonight <url> via ',
#  '"pga awards tv nominations include better call saul, mad men and inside amy schumer: on tuesday, the ... <url> tvupdate"',
#  'photos: beautiful! selena presenting amy schumer with an award at the 19th annual hollywood film awards! <url>',
#  'saw trainwreck for the 2nd time &amp; again found it &amp; amy schumer brilliant as was the screenplay she wrote. mel brooks agreed.100%',
#  'selena gomez presented amy schumer with an award and a heap of praise at the hollywood film awards on november 1.',
#  '"selena gomez, amy schumer get cuddly on the red carpet: see the cuteness here!: <url> videos may"',
#  "some may find it tragic that i'm sat alone watching amy schumer and eating ben and jerries but personally i feel no shame",
#  'the only reason i keep going is that i get to see amy schumer in june',
#  '"watching ""trainwreck"" for the 2nd time with my girls. hilarious!!! love amy schumer! trainwreck johncena amyschumer"',
#  '"watching \'inside amy schumer\' for the 1st time. she\'s funny, sassy, smart, beautiful...&amp; sleeps with a teddy bear in one sketch. i\'m hooked."',
#  'watching amy schumer for the 1st time...so funny! i must have been living under a rock or something',
#  'watching amy schumer: live at the apollo makes me so excited for sunday when brings ',
#  '"watching the pogues\'s ""fairytale of ny"" for the 9th time today and is it just me or does kirsty maccoll look kinda like amy schumer?"',
#  "well kid's it's friday. so rejoice. another week is done. the hell with trump i'm voting for amy schumer.. white house bound ",
#  '"when it comes to body empowerment and feeling comfortable in your own skin, amy schumer is the role model we look up to. on thursday"',
#  "who was the best 'saturday night live' host? amy schumer. 50% of voters agree with me. <url>",
#  'who went to the first amy schumer show on saturday? anyone who would be willing to talk to me about it? <url>',
#  '"will smith, amy schumer and carey mulligan were among those honoured sunday at the hollywood film awards, with... <url>"',
#  '"in them to do it. amy schumer in ew, october is a fucking rock star &amp; i love her &amp; jesus f\'ing christ we need more like this"',
#  "just another reason to love amy schumer and here's a piece on the calendar.. <url> <url>",
#  '"more meta-textually, ant-man may be the worst movie in the marvel universe for gender roles. of its... <url>"',
#  "ant-man was the 1st time i didn't stay for a marvel film's post credits scene. the film was just one big teaser. didn't need to see another.",
#  'as ridiculous as ant-man may have looked it was actually pretty damn good bigfan',
#  '"more meta-textually, ant-man may be the worst movie in the marvel universe for gender roles. of its... <url>"',
#  '"podgodz 165: podgodz 165 recorded 28 july 2015 i saw ant-man, i should not have. midroll sells to, i want to s... <url>"',
#  "reason why ant-man may have 'struggled' vs. other marvel? my parents assumed it was a parody.",
#  '"sorry gang, 2nd act of ant-man just kills my buzz. so boring and the writing is really bad. i\'m hoping this stuff wasn\'t in wright\'s script."',
#  "the only reason i'm watching ant-man is cause of 5$ tuesday this is definitely something you wait to watch at home",
#  ": can't spell star hotshots without the word short. go ant-man!!! <url>",
#  '"smartncaa: it\'s another \'yes para sa tres\' for the ""ant-man"" mark cruz! letran stil on top, 72-53 with 1:53 remaining in the 4th!"',
#  '"smartncaa: it\'s another \'yes para sa tres\' for the ""ant-man"" mark cruz! letran still on top, 72-53 with 1:53 remaining in the 4th!"',
#  '"// -- cinema this saturday. i would love to see ant-man, but he\'s not into marvel like i am, so i believe i\'m gonna have to give it a miss."',
#  '"// so, i thought ant-man was out of the question for the cinema saturday but my boyfriend said the films he\'s seen are \'awesome\' and that -"',
#  '"3rd time. antman with friends ( rogers 18 theater for ant-man in rogers, mn) <url>"',
#  "5 days off now! bit of golf on the agenda and a few other bits. looking forward to watching 's ant-man on thursday too!",
#  " i've got mon. off work &amp; i'm going to see ant-man movie in theaters. want to see it in 3d.",
#  ' saw ant-man at amc eastchase 9 in fort worth. 1st time at the theater. great experience for my wife and me!',
#  '" here it\'s 1:20 pm, i can be around that time but maaaybe i\'ll be gone since i may watch ant-man today"',
#  ' i finally saw ant-man on tuesday it was so good &amp; entertaining also i enjoyed the spider-man reference',
#  " we're going to see ant-man tomorrow. i figured it would seem even better in comparison after watching this. :)",
#  " just watched the show. great show. couldn't agree it's about ant-man. see ya thursday",
#  ' ant-man was 1 for the 2nd straight week domestically. never has this been more apropos. <url>',
#  " so i'm a bit late but i watched ant-man. it was amazing and great job! can't wait for the 2nd one!",
#  '" hi eve, i hope you enjoyed ant-man! saverday tuesday is all day &amp; prices can be found here in future: <url>"',
#  '" i went to see mission impossible rouge nation today, i really enjoyed it. have u seen it? i might go see ant-man tomorrow?"',
#  '" i had high expectactions when i watched because everyone was hyping it so much, i knew ant-man would be good after 1st trailer"',
#  '" you definitely aren\'t, ant-man was my 2nd favorite phase 2 flick right after winter soldier"',
#  ' took my son to see ant-man yesterday and the forceawakens trailer played before. 1st time seeing it on big screen. awesome',
#  '" probably see ant-man at the cinema tomorrow. ) i hope you enjoy your tea, i\'m certain you will. x"',
#  '" there are a few winks in winter soldier and ant-man, various iron mans. largely, though, you may be right."',
#  '" i am so hyped for tomorrow, the clip at the end of ant-man was enough to get me excited"',
#  " they are great aren't they - i have one from the ant-man wave coming tomorrow as i want to build the ultron figure.",
#  '" yeah, ant-man fails on jan and her daughter, but it\'s still a better movie than ff according to reviewers i trust."',
#  '" horrible. diehard fans may love the hard r, but lots of people will pass. ant-man was fun, quirky, enjoyable. not this."',
#  '" na if they know wa good for them it will be like ant-man, mar-vell would give carol danvers the mantle"',
#  '" yeah, on friday i went and saw two movies people bitch about - ant-man and minions. i had a good time! hatersgonnahate"',
#  '" fair enough. unrelated, think i may go see ant-man again tomorrow if you\'re interested."',
#  '" i\'m gonna see ant-man tomorrow, can\'t wait. (you seeeee, i\'m doing theaters lol)"',
#  '" it\'s horrible, complete fail compared to the 1st movie. rather watch ant-man or entourage."',
#  '" hoping to see ant-man tomorrow night at the everyman in reigate... apparently it\'s been refurbished and is pretty good,"',
#  ' you and me both. was chatting to about 4th wall breaking after ant-man',
#  ' do you want to see ant-man on tues?',
#  ' my whole family is going to see ant-man on friday before they leave though',
#  ' love winter soldier. incredibly close 3rd cause of its ramifications on the mcu. but i had too much fun with ant-man.',
#  '" i finally saw ant-man on tuesday i really enjoyed it, the movie was so good &amp; entertaining &amp; i enjoyed the spider-man reference"',
#  '" then again, this is coming from the girl who just saw ant-man for the 3rd time"',
#  ' may still be out there (avengers). am looking forward to ant-man and heard it si totally awesome!',
#  '" i understand, you enjoy ant-man and assure you it will start on time when you return tomorrow"',
#  '" i\'m a dumb, the missus booked a sofa at the electric tomorrow for ant-man. fancy it tomorrow?"',
#  'a special tuesday night movie with nephew today. we went to see ant-man. it was much better than i had anticipated. a nice old school vibe.',
#  "also good news i'm going to go see ant-man tomorrow /twerktwerk",
#  'ant-man: screening: sat &amp; sun 1.00pm super tue 6.00pm armed with the astonishing ability... <url>',
#  '"also tomorrow on <url> you\'ll find my review of ant-man. that\'s right bitches, i actually saw a new film at the cinema!"',
#  "ant-man at amc cinema suites on a sunday afternoon is a great choice. good film. have to see it again cause missed 's scene",
#  '"ant-man feels like a rough 1st draft of the marvel universe (namely iron man) which it probably was, considering it\'s where it all started."',
#  '"ant-man felt like the 1st ironman movie 2 me. that\'s good. it did feel like 2 films grafted onto each other. not as good, but not bad either"',
#  'ant-man is here through the 30th!! antman summer <url>',
#  '"ant-man is important. no matter how small his role in civil war may actually be, he is still there for a reason. don\'t downplay him."',
#  "ant-man is one of the funniest marvel movies we've watched. check out our spoiler free review! <url> <url>",
#  '"ant-man may have cliched and formulaic structure, but it\'s a whole lot of fun. the final 40 mins is superb."',
#  '"ant-man premieres tomorrow night in doha. a savior from the atrocity that was ""pixels."""',
#  'ant-man review coming tomorrow hope to see you all their! fandomreviews youtube',
#  '"ant-man starts tonight! pg-13. showtimes 7pm each night, 4 &amp; 7 weekends. monday matinee, august 17th., - fried... <url>"',
#  'ant-man starts tonight! runs fri-mon at 8:00pm nightly &amp; is rated pg. see you at the movies :) <url>',
#  'ant-man takes a second week at the top of the box office: while it may not be setting th... <url> via ',
#  'ant-man tomorrow hopefully and i kind of want to give fantastic four a shot also .',
#  '"ant-man tomorrow. looking forward to it, but some asshole ruined it for me."',
#  '"ant-man was brilliant. inside out was spectacular. what a great year for movies so far. loved today, just sat in the cinema!"',
#  'ant-man was even better the 2nd time',
#  '"ant-man was high on my list to see, but didn\'t get the chance until tues night. it was such a fun movie! ant-man v falcon...classic!"',
#  '"ant-man was ok. loved the action, first hour dull, 2nd hour great, villain was actually a good villain."',
#  'ant-man was ok. nothing amazing but marvel evil for having me sit through the longest credits to see the 2nd end credit scene.',
#  '"ant-man, edge of tomorrow, inside out, inglourious basterds and obvious child (my favourite of the week) myweekinmovies"',
#  '"ant-man is getting good reviews, might have to go watch it sunday night"',
#  '"ant-man tops north american box office: marvel action flick ""ant-man"" stayed atop the us box office sunday, ... <url>"',
#  '"ant-man was good tho. and props to the guy who mention about the 2nd extra scene at the end of the movie, you da real mvp."',
#  'anybody want to see ant-man tomorrow?',
#  '"anyway, i\'m going to the theaters tomorrow to watch ant-man! i\'m really excited. ;o;)b"',
#  'back from ant-man for the 2nd time! love that film.',
#  '"back to work tomorrow so off to the cinema to finally watch ant-man with jackson. heard good things, plus it\'s marvel... it\'s gonna be mega!"',
#  '"been a little busy lately, just now getting to see ant-man. oh and i\'m a child! west 21st st. warren <url>"',
#  '"been an ant based week, first seeing ant-man at the cinema. now visiting antwerp. maybe i\'ll finish with meeting ant &amp; dec? hopeful"',
#  "best part of ant-man is how hank pym's treasured photo of his wife covers up her actual face with a large sun hat.",
#  'box office: ant-man avoids a trainwreck with $22.6 million friday for no. 1 ... - hitfix <url>',
#  '"breakingnews: \'ant-man\' wins box office for 2nd weekend with $24.8 million haul, edging out \'pixels\' - usatoday <url>"',
#  '"cannot wait to see ant-man and southpaw with tomorrow! i need this downtime, badly!"',
#  'catching up on films tomorrow with 2nd watch of ant-man in 3d. then 1st watch of maggie and southpaw.southpaw films <url>',
#  '"catching up on movies before they leave theaters. trainwreck was as good as everyone says it is. tomorrow, ant-man."',
#  'congrats to disney for managing to keep ant-man as the 1 movie for a 2nd weekend with a paltry $24.7 million take. boxoffice',
#  'continuing to bond with the offspring via marvel movies with another superhero saturday thanks to a very funny ant-man. fb',
#  '"don\'t forget all films before 5pm are just a fiver for all! valid mon - fri only. book now and enjoy ant-man,... <url>"',
#  "dragon ball z tomorrow but i don't know if i want to wake up early to see it at 12 ... when i can see f4ntastic or ant-man at a later time",
#  '"ends this thursday. have you seen marvel\'s ""ant-man"" yet? <url>"',
#  'episode 39: ant-man the comics is out now to hold you over until episode 40 arrives on wednesday! <url>',
#  '"fyi, the inspiration 4 ant-man has been turned into a miniseries by and it\'s out tomorrow, theshrinkingman, themoreyouknow"',
#  "fantastic four tomorrow will it be as good as ant-man we'll have to see",
#  'final shows for pixels &amp; ant-man are thursday! opening wednesday: shaun the sheep &amp; thursday: fantastic four!',
#  '"finally going to see ant-man tonight, then off to see rogue nation either tomorrow or sunday. looking forward to both."',
#  'finally going to watch ant-man tomorrow its still getting good ratings excited',
#  'finally got around to see ant-man and absolutely loved it. nice way to cap off an eventful saturday.',
#  '"get paid on friday and all i can think about wanting to do is go to the cinema to watch ant-man, too many good looking films coming out"',
#  'going to fantasticfour tomorrow. half expecting the box office girl to give me a sad look and say i can see ant-man a second time instead.',
#  'going to go see ant-man on monday morning. i have the best life.',
#  "going to go see ant-man tomorrow hope it's good",
#  '"going to see ant-man today for the sunday matinee, just need to put the roast beef in the crockpot and i\'m good to go! :d"',
#  '"going to the movies tomorrow to watch southpaw, paper towns, train wreck and then ant-man again."',
#  '"gonna go to the city this weekend (saturday most likely), shop a bit and watch ant-man, cause hell, i wanna see it!"',
#  'gonna wait until tomorrow to see ant-man and take my ma with me.',
#  'got to love these three dedicated days of laziness. back to gyming it up tomorrow. before ant-man.',
#  'great to see sun girl in last days of ant-man. be great if she survived secret wars! do the right thing =) <url>',
#  '"heroes! well, almost. these four lucky residents scored gigs in \'ant-man.\' check out the story tomorrow! <url>"',
#  '"had a slightly intoxicated conversation about daredevil, ant-man, civil war, &amp; the mcu. if that\'s not a successful wednesday, then what is?"',
#  'had the chance to finally see both the fantastic four and ant-man. if i may indulge in a pun... big things do come from small packages.',
#  '"he\'s a handsome devil, isn\'t he? catch him in ant-man, screening for the last time tomorrow! <url> <url>"',
#  'hey students! do you like movies? then join us tomorrow at cinemark 6 at 12:30 pm for ant-man! the movie starts at 12:50 pm. see you then!',
#  'hi how the editing of your new video coming along? up tomorrow ? waiting to watch it. ant-man opens here tomorrow',
#  '"i *could* see ant-man today, or, i could see the live action attack on titan movie in theatres tomorrow...."',
#  'i debate seeing ant-man tonight for the 3rd time...do i?',
#  '"i don\'t know what i\'m more excited about - starting a new hub8 project, seeing ant-man or charlie coming home from greece tomorrow..."',
#  'i finished first at timeplay when i saw ant-man tonight. i think i may have peaked. antman dreambig',
#  '"i got 3 options on friday suck it up and watch fantastic four watch ant-man, again or watch mission impossible:rogue mation"',
#  '"i had a really great time watching ant-man, reminded me of the 1st time watching iron man , where the character tries to learn who he is"',
#  '"i had this written at like half 6 today and almost forgot to post it! <url> featuring wilco, ant-man, whas and more."',
#  'i have my agent carter t shirt and my jan earrings. the concession stand guy said stay till the end. as prepared for ant-man as i can be?',
#  '"i may be late to this party, but ant-man is a great movie! ranks among my top picks in the marvel cinematic universe, i didn\'t expect that"',
#  'i need to get up early tomorrow and finally see ant-man. my local cinema only has one showing and it is just after 12pm.',
#  'i plan to see the fantastic 4 movie tuesday. i went to see age of ultron and ant-man the thursday night before.',
#  '"i saw ant-man on friday night, but peeked in the showing of soc to see the response. packed showing with racial mix. <url>"',
#  'i should go watch ant-man tomorrow because i really want to watch it and have yet to see it.',
#  'i think the best stan lee cameo may be in ant-man. it had me laughing hard.',
#  'i want to trade an ant-man fig for this yellowjacket. all from june box. tweet if interested <url>',
#  'i watched ant-man for the 3rd time today.',
#  '"i would say, ant-man is probably my favorite movie of the year so far with mi: rogue nation at a very close 2nd"',
#  "i'll end the streak of bad movies tomorrow when i go to ant-man again",
#  '"i\'m desperate enough to go see ant-man, but it won\'t be out until august 12 here."',
#  '"i\'m going to see ant-man. wednesday, 19 august 2015 at 14:00 in newport - spytty park <url> cineworld"',
#  "i've decided to record the new comically on the history of ant-man a day early...i may even have it ready for release tomorrow.",
#  '"if i can finish this final tonight, i\'ll be able to finally see ant-man tomorrow after work."',
#  "if i feel up to going to mum's eye check up may try and see ant-man",
#  "if you liked ant-man you may enjoy law and the multiverse's discussion of the whole robbery/burglary distinction. <url>",
#  '"if you\'re having doubts about ant-man, just go and see it, you won\'t be disappointed. he may not be a major character, but the movie is good"',
#  'ima just go catch a matinee of ant-man by myself tomorrow lol',
#  'in other news i saw ant-man! it may have a few flaws but i absolutely loved it! so funny and the character is brilliant',
#  '"in other news, can\'t wait to see ant-man tomorrow night, hopefully it\'s what i expect"',
#  "isn't that what a bruce jenner nephews call him? ant-man wins box office for 2nd weekend with $24.8m <url>",
#  'it seems the rest of my life may just be convincing people to watch ant-man with me.',
#  '"it\'s another sunday with perfect cinema weather, so head down for inside out and ant-man worthing book at <url>"',
#  '"it\'s official: finally get to go see ant-man tomorrow!! first real day off in 2 months!! so stoked- no spoilers, marvel nation!!"',
#  "it's the first of august and started off good with ant-man.",
#  "just found myself googling 'ant man quantum realm reflection'. i may be thinking about ant-man too much. it is ace though.",
#  "just saw ant-man in the theatre for the 3rd time. it's still super great.",
#  "last day for ant-man! mission impossible rogue nation opens fri! i am so impressed with this movie! don't miss it! <url>",
#  '"looks like ant-man is gonna hit 1 for the 2nd straight weekend. not to mention, also pass the $100 million mark. not too shabby........"',
#  "m:i 5 was... ok. nowhere near as awesome the 4th was. glad i didn't spend $11 at the theater for it. i would rather watch ant-man again.",
#  'many blessings lately: &amp;nbsp;&amp;nbsp;&amp;nbsp;&amp;nbsp;&amp;nbsp;got out to the theater last saturday to see ant-man . not only <url>',
#  '"marvel kicks off the presentation! alan horn starts by praising ant-man\'s 1 opening, which he says is marvel\'s 12th consecutive 1 opener."',
#  'may go see ant-man tonight. anyone interested?',
#  "maybe on monday i'm going to see ant-man with the squad",
#  'michael douglas may not be coming back for another marvel film...he did so good in ant-man though',
#  'might just have to go see ant-man tomorrow',
#  '"my cousin snapchatted me ""ant-man tomorrow. you good?"" and these are the reasons we get along so well."',
#  'my dad and sister will try out daredevil series tomorrow. they really liked ant-man when i recommended it to them... hehehehehe!',
#  "my plan for tomorrow's surprise day off is to finally see ant-man.",
#  '"no work for the rest of the week means ant-man tomorrow morning, followed by a trip to the comic shop, and much lazing about."',
#  '"nothing like finishing the last day back to work with friday\'s, and ant-man."',
#  'now going to watch ant-man for a 2nd time and drving everybody...',
#  '"now that there\'s several 2d showings of ant-man a day, maybe i\'ll actually see it... like tomorrow."',
#  '"ohhhhh, do i see mi:5 or ant-man on friday at the cinema... hmmmm."',
#  '"okay, i forgive the makers of ant-man for omitting jan pym. it\'s a funny, exciting, heist film with a lot of honor to dads. go see it."',
#  "or tomorrow i don't care but i want to watch ant-man",
#  '"paid my bills, bought some groceries, did a bit of price-shopping on some clothes, and bought my ticket for ant-man later tonight. saturday"',
#  '"paul rudd stars as ant-man, showing tonight, tomorrow and sunday. rated pg-13. showtimes are at 7:15 each night.... <url>"',
#  "planning to watch ant-man tomorrow and see all the fuss about .... i hope i won't get disappointed .....",
#  'probably why marvel is waiting to show the civil war trailer until late sep/early oct to give ppl enough time to get caught up w/ ant-man',
#  'question... is ant-man any good? tempted to go watch it tomorrow',
#  '"recording a new fanboy versus tomorrow with and talking fantastic four, ant-man and more!"',
#  '"snap!: ant-man even with this being my 2nd time seeing it, ant-man still blew me away. best solo marvel film yet. truth"',
#  '"saturday movie reviews: ""ant-man"" is fun &amp; light <url> while ""woman in gold"" is tugs at the heart <url>"',
#  '"saw ant-man last sunday, and finally had time to draw it today. <url> <url>"',
#  'saw ant-man on tuesday. great film. much more character driven than the big epic mcu films.',
#  "saw ant-man tonight and loved it! here's my blog review: <url> any views appreciated! antman marvel",
#  'saw ant-man tonight with friends. my 3rd time. fun.',
#  '"seeing ant-man on monday, finally. 9pm showing, so i\'ll be useless the next day. and i don\'t care."',
#  '"seeing ant-man tomorrow, flat, it just isn\'t worth $40 *more* to see it in 3d. we\'ll just have to use our imaginations."',
#  '"seeing ant-man for the 2nd time ( amc north point mall 12 - amctheatres for ant-man in alpharetta, ga) <url>"',
#  'shoutout to for going with me to see ant-man (highly recommend) and scoring us free ice cream yesterday. best 2nd to last day here',
#  '"so.. finally saw in ant-man, i thin i may have zoned out starin at her tho cuz i remember nothing the guy said except ""yes"""',
#  "somehow i was able to enjoy the 2nd half of ant-man in spite of my gleeful anticipation about all the ant-lamb jokes i couldn't wait to make",
#  '"somehow got wrangled into seeing ant-man again tomorrow with another group of friends. ehh, i don\'t mind much tbh"',
#  "star&gt;box office:ant-man stomps on the competition for 2nd weekend at 1:marvel studios' ant-man was 1 at t... <url> actors",
#  '"still really want to see ant-man, hopefully tonight or tomorrow."',
#  'summer is busy! saw ant-man with super heroes lilf and . tomorrow minecraft with and ',
#  '"sunday recovery continues with this, then ant-man <url>"',
#  '"sure, ant-man is a cool film, but make sure you know all your movie options. ... (vine by saturday night vine) <url>"',
#  '"swapped out broken franken-part in my car, saw ant-man with family, took a nap, wrote for a bit, ate ice cream. saturday: victorious."',
#  'tfw ur on ur way to see ant-man for the 3rd time',
#  '"the top 5 marvel cinematic universe films of phase 1 and phase 2: with the release of ant-man, phase 2 of mar... <url>"',
#  "the best cgi in ant-man isn't the ant scenes. it's that 1st scene with michael douglas' face. smhowzow",
#  'there are people who only watched ant-man for the upstate ny cameo and the 2nd credit scene. civil war is going to be pretty big.',
#  'thought about seeing the new fantastic four movie today. passed and saw ant-man for a 2nd time instead. lol antman fantasticfour',
#  '"tickets to see ant-man with and this friday! looking forward to it, heard such mixed reactions to the film"',
#  'tomorrow i wanna have dinner out and watch ant-man. who wants to come with me?',
#  '"tomorrow is the last day to see ant-man so mission: impossible rogue nation can begin friday, july 31st. to see... <url>"',
#  "took the day off work and treated babe to some big biscuit and saw ant-man. some monday's aren't too bad.",
#  '"trying to get tickets to the ""ant-man"" preview showings on wednesday. the theaters are fucking packed, bro. i\'m kind of happy...paul rudd!"',
#  'unexpected development-- saw ant-man on saturday night in london. it was surprisingly charming. i actually quite enjoyed it.',
#  '"very excited to see ant-man tomorrow but after i\'ve seen it, i will have seen all mcu films this yearaka i have to wait 9 months for another"',
#  "was gonna see inside out again tomorrow but i found it a bit disappointing so we'll probably watch ant-man again",
#  '"watched ant-man for the 2nd time today, and thought of 2 more reasons to see it again: to catch the easter eggs and catalog its britishisms."',
#  '"watched ant-man for the 3rd time for free, technically because it\'s with family. :)))"',
#  'we hope you are enjoying pixels. ant-man will start this friday. armed with a super-suit with the astonishing... <url>',
#  '"we saw ant-man last saturday - it was very good. proves that no matter your size, you are still a super hero! <url>"',
#  'we will be highlight our guests every monday for cmx2015 and we are kicking it off with sara moni! with ant-man... <url>',
#  '"wednesday is movie day! we recently saw ant-man, southpaw and amy (the amy winehouse documentary). what have... <url>"',
#  'what are the chances of ant-man still being in theatres on august 20th when i get to halifax?',
#  "who wants to go see ant-man tomorrow? i believe it's a film about a man who's imbued with all the powers of a guy named anthony.",
#  'who wants to see ant-man with me tomorrow ://',
#  '"why it\'s great to go see ant-man in imax (or any movie, really), at the tuesday late night showing. <url>"',
#  "will someone go see ant-man with me tomorrow? i'm dying to see it",
#  'can it just be 5:30 tomorrow evening already because ant-man will be over by then and the post credits will begin <url>',
#  '"going to see ant-man today then will get pasta, i\'m doing all my birthday stuff today because i have band camp tomorrow and that\'s all day"',
#  '"it\'s crazy how i swore up &amp; down that ""ant-man"" would stink but i\'m excited to see it a 2nd time."',
#  "just booked my tickets for ant-man for this friday. can't wait!",
#  'might as well go see ant-man for the 4th time again since its release..',
#  '"proper geeking out today; ant-man was so good and under the dome till i sleep, mate im gonna be dead tomorrow"',
#  '"seeing ""straight outta compton"" &amp; ""ant-man"" tomorrow is the move.. gotta decide on a 3rd movie as well."',
#  'should i force my dad to go to the cinema with me and watch ant-man (that would be my 2nd time watching it) (i missed the post-credit scene)',
#  'thinking about the number of people who may have discovered the cure through ant-man makes me so happy',
#  'why pack for moving to college tomorrow when you can watch three different trailers for ant-man instead',
#  " may i remind you she's kida hot is number one on the itunes chart while bad blood is at number 50 play the more popular one",
#  '" no more bad blood by taylor swift music please, the video on monday was more like badluck!!! badeditor sfgiants cheesymusic"',
#  ' a response to bad blood may make the album ugly.',
#  "bad blood is not a music video it looks like a pepsi super bowl commercial. it's 5 minutes of cameos to a song with 6th grade lyrics",
#  'bad blood is such a terrible fucking song. i just listened to it for the 1st time and i feel like god took a shit in my ears',
#  "bad blood may have the absolute worst lyricism i've ever heard in my life (regarding taylors parts) usedtobemadlove reallydeepcut",
#  "discussing the t swift vs k perry feud with boyf (he was unaware). he's a big fan of both. he says he's torn. may have to boycott bad blood.",
#  'i like taylor swift as much as the next man but bad blood may be the single worst song ever created in the history of mankind.',
#  "if it were blank space up for 7 awards tomorrow taylor would sweep but since it's bad blood she'll probably only win 5/10",
#  '"it\'s kinda awful when you can relate to that ""bad blood"" song. bc it\'s my life monday thru thursday. i did nothing! and if i did tell me!"',
#  '"just gonna say it: the lyrics in ""bad blood"" sound like they were written by a 7th grader. ""done"" doesn\'t have two syllables, taylor."',
#  "listening to bad blood on the radio 1st time: this is awful 8: people like this? 15: that bass line isn't so bad now: now we got bad blood",
#  '"miley doesn\'t like the ""bad blood"" video, says things about drugs etc <url> <url>"',
#  "my parents' car rendition of bad blood may actually kill me one day",
#  '"nieces were play taylor swift...i submit that ""bad blood"" may be the worst lyrical train wreck in music history. just abysmal shit. duh-un?"',
#  '"taylor swift\'s song ""bad blood"" may be the most annoying song that\'s currently playing on the radio toorepetitive"',
#  "that taylor swift 'bad blood' may be the worst quality/budget music video i've ever watched",
#  '"thesecret says visualizations come true, so tomorrow night is bringing me on stage for bad blood, you guys."',
#  '"1st day training taylor swift for her mv ""bad blood"". she was a sweetheart and picked up quick! <url>"',
#  '1st thing i did after baggage claim was get up to date with . bad blood ronna &amp; bev style makes being home a bit more okay',
#  '" i will be spending my friday night listening for taylor swifts ""bad blood"" on the 1 radio station virgin radio 99.9 :)"',
#  '" doing a xf3dayhiatus watch over the weekend! sat bad blood, sun arcadia, mon pmp all at 8pm est - join in the fun!"',
#  '" let\'s see, there\'s ""good vibrations,"" trap queen, ""bad blood,"" .... can\'t remember what he uses for 4th at-bat."',
#  '" you may not like the song but that doesn\'t change the fact that it was a big deal.""anaconda"" broke a record before ""bad blood"""',
#  '" i love taylor swift i\'m going to her concert on september 13, i love all of her songs especially bad blood she is my idol!"',
#  '"anaconda\'s a music video gem, but t-swift\'s bad blood is in a classic comedy vault--it\'s the best of its kind since rebecca black\'s ""friday"""',
#  "bad blood (feat. kendrick lamar) by taylorswift is uk's top 36 on the singles chart as of the 17th of july 2050",
#  'bad blood by kendrick lamar and taylor swift may be my guilty pleasure of the year. i wish more mainstream pop was like this.',
#  'bad blood by taylor swift feat. kendrick lamar stays in top 5 for 11th week on the billboard hot 100; peaked at 1',
#  '"bad blood drops next friday! hyped! theghostisneartour is in gettysburg tonight, so come hang! <url>"',
#  '"bad blood has just reached 400,000,000 views on . it\'s taylor swift 4th video to do so. <url>"',
#  '"bad blood is 1 at pop radio for a 6th week! to celebrate, i\'ll be posting behind the scenes videos: <url>"',
#  'bad blood is 1 at pop radio for the 6th consecutive week!! <url>',
#  "bad blood is winning voty tomorrow (even though it should've been blank space)",
#  '"bad blood now has more than 400m views,it\'s selena\'s 1st feature to reach this and cagi is coming"',
#  'bad blood playing in the salon on eastenders has been the highlight of my friday night',
#  'bad blood was playing as i entered bullwinkles for the first time last night and i may have had an out of body experience??',
#  'cool for the summer good for you lean on bad blood see you again <url>',
#  '"elwira will be singing bad blood, may the god\'s be with her idolssa"',
#  '"honestly, i\'m liking kendrick\'s ""bad blood"" verses a lot more now. may be able to elevate the song to being really good to me."',
#  "i am listening to 's (with ) version of bad blood for the 11th time this night.hope you come to australia with pmj",
#  '"i love ""bad blood"" and i love the music video, but it is just taylor acting a damn fool. like c\'mon."',
#  '"i\'ve just kind of sat here for an hour doing nothing but listening to bad blood on repeat, this is normal"',
#  "ian mckellen reciting taylor swift's bad blood lyrics is just amazing <url> <url>",
#  '"in addition to bad blood, my brain is also shuffling the wonder woman theme and california gurls. still better than november rain."',
#  '"jess glynne has a song called ""bad blood"" on her new album &amp; i\'m seeing her in november &amp; i hope she does a bb/bb remix."',
#  'just another typical saturday!!!! madison is reenacting the bad blood video with her dolls',
#  '"last day of the best tour i\'ve been on. ""bad blood"" single / single on friday. life rules! <url>"',
#  'lord and i killed the floor friday when bad blood came on!',
#  'nah bad blood was the summer anthem <url>',
#  '"noah\'s 3 fav songs in order: 1) the imperial march 2) bad blood (""why does she need bandaids?"") 3) shake your booty"',
#  '"nothing better than a pump-up video to a song. ""bad blood"" coming to you at vs cosmos on sat. mymasterpiece"',
#  '"seeing tomorrow at lifelight! hoping a cover of ""bad blood"" is included in the set list!"',
#  'september 6th and bad blood is still the best song of all time',
#  'short drive to work this morning with bad blood--raspberry beret--out of style as my soundtrack. tuesday gonna be a good day.',
#  "someone hangout with me tomorrow so i can show them the dance i made to bad blood. it's pretty fucking sick.",
#  '"tay tay is in a roll i know im realizing this kinda late but c\'mon she is on a roll baby!! style, blank space, bad blood"',
#  '"taylor is going to dominate when the nominations for the vmas are released tomorrow, blank space and bad blood were very well made videos."',
#  '"this is soooo good! sunday jam "" covers taylor swift\'s bad blood in the live lounge"" <url>"',
#  "wow! 's bad blood is 1 at pop radio for the 5th week.",
#  '"watching the bad blood premiere at thestangrammys, but planning to release feeling myself vid tomorrow. <url>"',
#  'we met at our 1st eat to the beat event at &amp; love her cover of bad blood by ff <url>',
#  '"why do i not remember seeing ""bad blood"" when it 1st aired? hilarious episode!"',
#  '"guys vevo may not be updating, bad blood took 3 months to get 3m likes, we could\'ve broken the record. keep refreshing dragmedownmusicvideo"',
#  '"i really sat through, and watched bad blood music video, becos i found out my gf was in it."',
#  '"throwback 4 \'s poster of bad blood, in honor of taylor\'s award on vmas last sunday. the law got the power <url>"',
#  '"whenicaught saturday night fever, i quit my job, moved to brooklyn, and listened only to the bee gees."',
#  '" may i suggest boogie wonderland by earth, wind &amp; fire. maybe a little bit of tragedy by the bee gees"',
#  " well their 1st 3 fell behind george michael's faith &amp; the bee gees' you win again.",
#  ' saturday night live with bee gees or take that?',
#  ' people forget how good the bee gees were before saturday night fever',
#  '" bee gees always been a favorite...musical genius! their music soundtrack made the film, saturday night fever. love them!"',
#  " it's also reminds me of bee gees song for saturday night fever soundtrack.. 70s vibe",
#  ' i may have gone to an australian bee gees tribute show because of the barry gibb talk show...',
#  '"at 97 100numbertwos50s60s in sep \'69 taking over at 2 from robin gibb, the bee gees\' don\'t forget to remember <url>"',
#  "bee gees - saturday night fever (john travolta) [hd] yeh boyy you know you're all dancing and sing to this one!!! <url>",
#  'bee gees with fanny (be tender with my love) for our sunday listening pleasure. <url>',
#  '"come and see bee gees fever at theatre on the steps, bridgnorth this friday and saturday. tickets nearly gone...don\'t miss out!!"',
#  '"downtown halifax on a wednesday night: extremely tough-looking biker in full leathers roars by, radio blaring the bee gees."',
#  'ending our thursday we have.... bee gees with immortality <url>',
#  "for our wednesday morning we have one from the 60's starting us off.. bee gees with kitty can <url>",
#  '"good driving/singing tunes the bee gees, might have to dust the \'best of\' down for some falsetto fun! <url>"',
#  'happy friday everyone...starting off we have... bee gees with country woman <url>',
#  'happy saturday!!!! bee gees with how deep is your love <url>',
#  'happy sunday..... bee gees with walking on air <url>',
#  'i just heard the bee gees more than a woman blaring at 120 dbs in the street in front of my apt. its saturday night in the city lol',
#  '"i just liked this song ""and the sun will shine"" by bee gees <url> <url>"',
#  'i know your eyes in the morning sun i feel you touch me in the pouring rain bee gees',
#  'i love the bee gees version but i may love this one a little more. <url>',
#  "i'm having this problem wherein i watched saturday night fever yesterday and now i can't stop listening to the bee gees.",
#  '"it\'s sunday night. everybody\'s lamenting work. so let\'s live it up one last time this weekend, with the bee gees! <url>"',
#  '"like the bee gees, the 2nd time around, jesus/emmanuel will become a word jonathan said...anti-fragile correct ... <url>"',
#  'made it to wednesday and starting off we have... bee gees with jingle jangle <url>',
#  'madonna was on saturday night live with bee gees last night :) she is perfect',
#  "morning everyone!! starting off our tuesday we have.. bee gees with i don't wanna be the one <url>",
#  'nu op radio zaanstad bee gees - will you still love me tomorrow 1',
#  'posting another song for our saturday as i feel like it.... bee gees with night fever <url>',
#  '"saturday night fever - more than a woman (bee gees) <url> via travolta, just travolta! wow!"',
#  "starting off our thursday we have for our pleasure.... bee gees with i can't see nobody <url>",
#  'sun the bee gees really have chuneeee',
#  'surprised to discover this morning that the bee gees are actually a good antidote to m <url> <url>',
#  'the bee gees into their 5th decade along with me in life. like barry and myself.......alone. <url>',
#  'the sound of sunday with bee gees - alive <url> webradio internetradio',
#  'then the bee gees came on...and i had to tuesday tuesdaytestimony <url>',
#  '"tie between ""september"" by earth, wind, &amp; fire and ""how deep is your love"" by the bee gees <url>"',
#  "tomorrow night it's the bee gees at cabaretsupperclub gonna be a brilliant night! <url>",
#  'what a feeling reminds me of bee gees song in saturday night fever movie soundtrack you can check it outttt it has some vibe of it',
#  'wishing everyone a happy saturday. our song for today is.... bee gees with i could not love you more <url>',
#  "yes i am spending my friday night listening to the bee gees on loop. don't hate.",
#  'you win again - the story of the bee gees thu 19 nov | 8pm the story of the bee gees! this incredible musical... <url>',
#  "'don't tell the bride' really is dreadful - i think it may actually be worse than 'big brother'",
#  "'this programme features indiscrete discussions about the royal family which may distress some viewers' weirdest warning ever on big brother",
#  " this may be the stupidest season of big brother yet. everyone can see what's going to happen! no one has balls! makeamove",
#  " im not watching no more to watch meg and james be bullyed canceling feeds friday i'm done with big brother",
#  '" this doesn\'t feel like big brother, but rather an episode of ""are you smarter than a 5th grader?"""',
#  '" the only thing you will hear tomorrow is ""all big brother 17 contestants have died of food poisoning"',
#  ' dude - u are killing me with the big brother spoilers. i may have to unfollow u until the season is over lol',
#  " isn't tna's tv deal gonna be done by the time big brother ends? austin may want to find jeff jarrett's number....",
#  '" the judgement of someone\'s tv fandom from someone who enjoys the bachelor and big brother is worth sh*t. night, see ya tomorrow!!"',
#  '"bake off, strictly, big brother, x factor. it\'s the tv equivalent of reading the sun. what\'s wrong with us? are we ashamed of intelligence?"',
#  'big brother is actually painful. can it please be thursday already?',
#  "big brother was annoying to watch tonight. they all decided to keep an obviously strong opponent over a weak one??? c'mon..",
#  'cant go to class tomorrow too stressed about big brother',
#  'celebrity big brother has dipped below 1million viewers for the first time ever in its new saturday timeslot: <url> cbb',
#  'celebrity big brother reminds me of that simpsons halloween episode when all those awful celebrities are on a plane to the sun.',
#  '"celebrity big brother starts tomorrow. i won\'t be watching, what a load of shit, the majority of them won\'t even be celebs. shit tv"',
#  '"chris christie thinks talk of the 4th amendment is ""hot air""? he puts the ""big"" in big brother."',
#  '"good grief big brother, can\'t you get a handle on the ants yet? every season...ants. c\'mon, fix the problem. bb17"',
#  "i can't believe it's been 12 years since i lost my big brother. today is his birthday and tomorrow is mine. when... <url>",
#  "i should really stop watching big brother: after dark cause it's only sunday and i already know the nominees and who won the veto...",
#  "i thought big brother came on for the longest today and i just realized it's monday and the foolery comes on tonight.",
#  "if steve or johnny mac get evicted i may be done with this season of big brother. i can't stand james or vanessa either. bigbrother17",
#  '"is big brother playing games with u as well?? i\'m stuck on same number since wed. am though i get 2 to 3 hundred fol a day, yes really! fbi"',
#  "it may be over for big brother... i'm just ready for survivor where getting blood on your hands is the name of the game!! cbs needs a revamp",
#  '"reviving big brother may have been channel 5\'s worst idea ever, and syndicating it may have been tv3\'s worst idea ever."',
#  'tv show ratings: mr robinson bows out steady with its finale on wednesday: big brother drops from i... <url> festivals',
#  '"the current celebrity big brother series may well have been the least watced, but the markmeets tea... <url> movie news"',
#  'this may be the worst big brother episode in history.',
#  'this may be the worst season of big brother bb17 will someone please make a big move!',
#  'this season of big brother is absolute garbage. if austin makes it in the finale i may throw up bb17 terrible castsucks',
#  '"try as i may, i just can\'t get excited for celebrity big brother or standard version. it needs a break for s few years cbb bigbrother17"',
#  '"watching some crap called ""big brother"". okay. i may have been out of the loop for some time now but,... wtf!!"',
#  'wednesday episodes of big brother are so boring now that there are no more battle of the block competitions.',
#  '"when scams a poor innocent girl out of 20c, after she sat in big brother for 2 hours. your pathetic, hosting rights removed."',
# ...
#  'brock lesnar reminds fans why he can beat the undertaker this sunday at summerslam. <url>',
#  'brock lesnar returns tomorrow on raw the fight will continue...',
#  "brock lesnar vs bo dallas at the msg show in october has been announced. it's like an early birthday present.",
#  'brock lesnar vs the undertaker match next sunday is going to be great.',
#  'brock lesnar will be facing the undertaker on august 23 make sure not to miss all you wwe fans out there.it could be the best match ever!!',
#  "brock lesnar's the best thing going in wrestling. there's not even a close 2nd.",
#  "can't wait for raw tomorrow! brock lesnar and undertaker in the same arena?!? wwe <url>",
#  "can't wait for raw tomorrow night. brock lesnar and undertaker both in the same arena. that's going to be awesome!",
#  '"can\'t wait to hear the huge pop for brock lesnar tonight, despite the fact that he\'s facing the undertaker this sunday. raw"',
#  "can't wait to see what's going to happen between the undertaker and brock lesnar on tonight's raw before summerslam this sunday",
#  'cringed a few times during that interview on felt bad for brock lesnar. summerslam is this sunday by the way',
#  "don't miss the beast brock lesnar on espn tomorrow morning! brocklesnar <url>",
#  "even though the undertaker may be old he's the only superstar in the current roaster that can stand up to brock lesnar!!! deadmanwalking",
#  '"every tuesday after i watch raw all i want to do all day is walk around sayin ""my client brock lesnar!"" before i start any conversation"',
#  'fuck i have an exam tomorrow but brock lesnar is on raw tonight uhhhh i pick the beast',
#  '"first time ever you hear ""boos"" for the undertaker! brock lesnar gonna beat his ass sunday!! wweraw"',
#  'getting pay-per-view tonight for 1st time in long time. will be cool.the undertaker vs brock lesnar! <url>',
#  "hey it's monday! which means monday night raw tonight! which means the undertaker &amp; brock lesnar!!",
#  "i can't wait for the main event of summerslam undertaker vs brock lesnar! may the best man win!",
#  "i can't wait tomorrow is the big day undertaker vs brock lesnar for the last time ever!! wwe summerslam",
#  'i do claim brock lesnar as one of the best ufc fighters ever because he is the 2nd person ever to win the title in only his 4th pro fight.',
#  "i feel like brock lesnar may be the only boyfriend that's safe dating rousey.",
#  "i had a dream that brock lesnar won the 3rd annual wmt because he f5d everyone. i woke up hoping it wasn't a dream.",
#  "i hope the oct 3 special from madison square garden (feat. brock lesnar) is broadcast on the network... 'cause this guy has ringside seats.",
#  '"i liked a video <url> wwe raw, brock lesnar and paul heyman addressed the ending of summerslam, aug 24,"',
#  '"i liked a video <url> relive the buildup to brock lesnar\'s clash against roman reigns: smackdown, march 26,"',
#  "i think it's fair to say that brock lesnar is winning this sunday raw ",
#  'i think that having undertaker on monday night raw and in a feud with brock lesnar is best for business! rawkansascity wwe',
#  '"i want to see brock lesnar f-5 david cameron this november. whaddaya think, ?"',
#  '"i\'m calling it now, monday, august 17th 2015, 9:45 pm brock lesnar will make undertaker tap out."',
#  "i'm still thinking about sunday &amp; last night. the undertaker &amp; brock lesnar are going to tare the house at summerslam wwe",
#  '"if tomorrow my wrestling promotion was up and running, it would be brock lesnar. you need someb... <url> wwe tna raw"',
#  '"it\'s wwe summerslam on sunday! we make brock lesnar 13/8 to take out the undertaker, who is 4/9. full odds here: <url>"',
#  '"it\'s 10pm. i\'m sat in my chair watching royalrumble, spaming with brock lesnar gifs. great night. <url>"',
#  'july 20th 2015 is a historic night thanks to the wwe raw and thedeadman for bringing in brock lesnar to start a riot wwe',
#  '"just keep watching brock lesnar and undertaker going at it on monday. absolutely brilliant! that\'s what went missing in the ""new era"" brawl"',
#  'kurt angle is the only man to pin or submit brock lesnar in singles competition from june-august in mma or pro wrestling. he did it 3 times',
#  "ladies &amp; gentleman it's time for monday night raw! and we start it off with the beast incarnate brock lesnar raw brocklesnar",
#  '"looking forward to monday night raw, the return of brock lesnar (and ). raw"',
#  'might just have to hit up monday night raw because brock lesnar is going to be there.',
#  'monday night raw in 1 hour john cena returns plus brock lesnar and the undertaker in the same building could go wild on usa network',
#  "monday night raw on tonight cena's back and brock lesnar and undertaker are back!",
#  'monday night raw!!!! time to play the game and hopefully brock lesnar will rest in tombstone city',
#  "my money is on john cena.. and brock lesnar... two of the best matches you'll get to see on sunday!!!!!!!!!!!!",
#  'never break the 11th comandment of the beast brock lesnar thy shall not intentionally provoke the beast',
#  '"on sunday, brock lesnar will have lived the dream of competing in a nyc-based ppv, which he wouldn\'t have done had he returned to the ufc."',
#  '"one of the best promo i\'ve seen in years. brock lesnar confronts the undertaker: raw, july 20, 2015 <url> via "',
#  "ooohh yeah i just remembered... i'm going to raw tomorrow!!!!!!! undertaker and brock lesnar!!!!!!!!! rawminneapolis",
#  '"rip bo dallas, we hardly knew you. loved this. wwe raw, bo dallas interrupt brock lesnar, aug 24, 2015 <url> via "',
#  '"replaying wwe july 13. if i was j&amp;j securities, i would never try to mess with brock lesnar. he\'s cool. omg"',
#  '"save the date, august 23 2015, summerslam main event, the undertaker vs. brock lesnar..gonna be epic..wwe"',
#  'i hear that caitlyn jenner may have to go to jail. i guess she committed manslaughter! <url>',
#  "i may talk my shit about caitlyn jenner. but i'm going to use her correct name and pronouns. that's the least i can do.",
#  '"i sat down two men today and all they could talk about was how nasty caitlyn jenner, i found their sexuality even more disgusting than hers"',
#  '"i think making caitlyn jenner into a halloween costume may be the definition of ""too soon."" <url>"',
#  '"in case you were wondering, caitlyn jenner is responsible for the death of a woman in a car crash in february. how courageous is she now?"',
#  "in case you're still calling caitlyn jenner a hero. <url>",
#  "it's looking possible that caitlyn jenner may be charged with manslaughter. serious question: does she go to a male or female prison??",
#  'just heard that caitlyn jenner may be charged with manslaughter after being involved in a fata... <url> via ',
#  'just watched the caitlyn jenner shit for the 1st time... ummmm he still sound just like bruce. never watching again',
#  '"me ""caitlyn jenner may get charged for manslaughter."" ""at least it\'s not women slaughter"""',
#  'prosecutors began reviewing evidence on tuesday in the fatal crash involving caitlyn jenner: <url>',
#  '"regardless of how ""courageous"" caitlyn jenner may be he still makes an ugly ass women lol"',
#  '"she may be trans, but she has 100 million to wipe away her tears from being discriminated against. i feel no sympathy for caitlyn jenner."',
#  '"since the crash happened in february, that means that they can\'t charge caitlyn jenner with manslaughter if bruce jenner commited the crash."',
#  'so caitlyn jenner may face man slaughter charges. he thought that the sex change would be easier for when she goes to prison',
#  'so caitlyn jenner may face manslaughter charges. the jokes just write themselves these days... transcriminal',
#  'so caitlyn jenner may face manslaughter charges? ironic she already slaughtered her manhood',
#  "the sun calls reactions to the caitlyn jenner costume a 'fan meltdown': <url> [paywall]",
#  "there's a 50/50 % chance that caitlyn jenner may be charged with manslaughter i should think so as well after what she did to poor bruce",
#  ...]

# %% [markdown]
# Next, I am dropping the 'Neutral' sentiments as my goal was to only differentiate positive and negative tweets. After that, I am filtering the tweets so only valid texts and words remain.  Then, I define the number of max features as 2000 and use Tokenizer to vectorize and convert text into Sequences so the Network can deal with it as input.

# %%
data = data[data.sentiment != "Neutral"]
data['text'] = data['text'].apply(lambda x: x.lower())
data['text'] = data['text'].apply((lambda x: re.sub('[^a-zA-z0-9\s]','',x)))

# print(data[ data['sentiment'] == 'Positive'].size)
# print(data[ data['sentiment'] == 'Negative'].size)
# print(data['text'].values)

for idx,row in data.iterrows():
    row[0] = row[0].replace('rt',' ')
    
max_fatures = 2000
tokenizer = Tokenizer(nb_words=max_fatures, split=' ')
# tokenizer.fit_on_texts(data['text'].values)
tokenizer.fit_on_texts(trainTweets)
# X = tokenizer.texts_to_sequences(data['text'].values)
a = len(X_train)
X = tokenizer.texts_to_sequences(trainTweets + testTweets)
# X_test = tokenizer.texts_to_sequences(testTweets)
X_train = X[:a]
X_test = X[a:]
# print(X_test)
X_train = pad_sequences(X_train, maxlen=32)
X_test = pad_sequences(X_test, maxlen=32)
# print(X.shape)
print(X_test.shape)
print(X_train.shape)
# print(X.shape)
# Out:
# /home/vaibhav/.local/lib/python3.6/site-packages/keras_preprocessing/text.py:177: UserWarning: The `nb_words` argument in `Tokenizer` has been renamed `num_words`.
#   warnings.warn('The `nb_words` argument in `Tokenizer` '
# (10550, 32)
# (4346, 32)

# %% [markdown]
# Next, I compose the LSTM Network. Note that **embed_dim**, **lstm_out**, **batch_size**, **droupout_x** variables are hyperparameters, their values are somehow intuitive, can be and must be played with in order to achieve good results. Please also note that I am using softmax as activation function. The reason is that our Network is using categorical crossentropy, and softmax is just the right activation method for that.

# %%
embed_dim = 128
lstm_out = 196

model = Sequential()
model.add(Embedding(max_fatures, embed_dim,input_length = X_train.shape[1], dropout=0.2))
model.add(LSTM(lstm_out, dropout_U=0.2, dropout_W=0.2))
model.add(Dense(2,activation='softmax'))
model.compile(loss = 'categorical_crossentropy', optimizer='adam',metrics = ['accuracy'])
print(model.summary())
# Out:
# /home/vaibhav/.local/lib/python3.6/site-packages/ipykernel_launcher.py:5: UserWarning: The `dropout` argument is no longer support in `Embedding`. You can apply a `keras.layers.SpatialDropout1D` layer right after the `Embedding` layer to get the same behavior.
#   """
# /home/vaibhav/.local/lib/python3.6/site-packages/ipykernel_launcher.py:6: UserWarning: Update your `LSTM` call to the Keras 2 API: `LSTM(196, dropout=0.2, recurrent_dropout=0.2)`
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_4 (Embedding)      (None, 32, 128)           256000
# _________________________________________________________________
# lstm_4 (LSTM)                (None, 196)               254800
# _________________________________________________________________
# dense_4 (Dense)              (None, 2)                 394
# =================================================================
# Total params: 511,194
# Trainable params: 511,194
# Non-trainable params: 0
# _________________________________________________________________
# None

# %% [markdown]
# Hereby I declare the train and test dataset.

# %%
# Y = pd.get_dummies(data['sentiment']).values
# print(Y)
# Y = np.array(trainSents)
Y_train = []
Y_test = []
for i in trainSents:
    if i == "positive":
        Y_train.append([1, 0])
    else:
        Y_train.append([0, 1])
Y_train = np.array(Y_train)
for i in testSents:
    if i == "positive":
        Y_test.append([1, 0])
    else:
        Y_test.append([0, 1])
# Y = np.array(Y)
Y_test = np.array(Y_test)

# print(Y)
        
# X_train, X_test, Y_train, Y_test = train_test_split(X,Y, test_size = 0.33, random_state = 42)
# print(X_train.shape,Y_train.shape)
# print(X_test.shape,Y_test.shape)

# %% [markdown]
# Here we train the Network. We should run much more than 7 epoch, but I would have to wait forever for kaggle, so it is 7 for now.

# %%
batch_size = 32
model.fit(X_train, Y_train, nb_epoch = 7, batch_size=batch_size, verbose = 2)
# Out:
# /home/vaibhav/.local/lib/python3.6/site-packages/ipykernel_launcher.py:2: UserWarning: The `nb_epoch` argument in `fit` has been renamed `epochs`.
# Epoch 1/7
#  - 8s - loss: 0.4192 - acc: 0.8309
# Epoch 2/7
#  - 7s - loss: 0.2504 - acc: 0.9034
# Epoch 3/7
#  - 7s - loss: 0.1950 - acc: 0.9273
# Epoch 4/7
#  - 8s - loss: 0.1418 - acc: 0.9487
# Epoch 5/7
#  - 7s - loss: 0.1018 - acc: 0.9657
# Epoch 6/7
#  - 7s - loss: 0.0763 - acc: 0.9740
# Epoch 7/7
#  - 7s - loss: 0.0571 - acc: 0.9795

# %%
print(X_test.shape)
print(X_train.shape)
# Out:
# (10550, 32)
# (4346, 32)

# %%
predicted = []
for x in range(len(X_test)):
    
    result = model.predict(X_test[x].reshape(1,X_test.shape[1]),batch_size=1,verbose = 2)[0]
    print(result)
   
#     if np.argmax(result) == np.argmax(Y_validate[x]):
    if np.argmax(result) == 0:
        predicted.append([1, 0])
# neg_correct += 1
#             predicted.append([0, 1])
    else:
#         pos_correct += 1
        predicted.append([0, 1])

#             predicted.append([1, 0])
#     if np.argmax(Y_validate[x]) == 0:
#         neg_cnt += 1
#         predicted.append([1, 0])
#     else:
#         pos_cnt += 1
#         predicted.append([0, 1])
        


# predicted = np.array(predicted)
# Out:
# [0.6961413  0.30385867]
# [0.8182419  0.18175809]
# [9.999746e-01 2.534618e-05]
# [0.009904 0.990096]
# [0.97434086 0.02565921]
# [0.00169556 0.99830437]
# [9.9986696e-01 1.3307290e-04]
# [0.00275828 0.99724174]
# [0.9981287  0.00187134]
# [0.848844   0.15115605]
# [0.9977343  0.00226568]
# [0.1479861 0.8520138]
# [0.06898191 0.9310181 ]
# [0.16849168 0.83150834]
# [0.66240937 0.3375906 ]
# [0.9401128  0.05988718]
# [9.9997532e-01 2.4633968e-05]
# [9.9950564e-01 4.9441023e-04]
# [0.9675713  0.03242875]
# [0.9654206  0.03457939]
# [0.9037839  0.09621608]
# [0.9816845  0.01831551]
# [0.9968123  0.00318771]
# [0.99886835 0.00113164]
# [0.96985346 0.03014649]
# [0.9848274 0.0151726]
# [0.8045309  0.19546914]
# [0.9408601 0.0591399]
# [9.9973232e-01 2.6765937e-04]
# [9.999982e-01 1.771573e-06]
# [9.9999428e-01 5.7439483e-06]
# [0.9973009 0.0026991]
# [0.01401199 0.9859881 ]
# [0.8952168  0.10478314]
# [0.99495053 0.00504943]
# [0.86515456 0.1348454 ]
# [9.9999511e-01 4.8855154e-06]
# [0.3400324 0.6599676]
# [9.9999750e-01 2.5402308e-06]
# [0.02857184 0.9714282 ]
# [9.9986732e-01 1.3264746e-04]
# [0.9350044  0.06499556]
# [0.00167334 0.9983266 ]
# [0.37052795 0.629472  ]
# [0.3328928 0.6671072]
# [0.77814966 0.22185037]
# [0.971057   0.02894304]
# [0.96975696 0.03024304]
# [0.9877989  0.01220099]
# [0.57306874 0.4269313 ]

# %% [markdown]
# Extracting a validation set, and measuring score and accuracy.

# %%
validation_size = 1500

X_validate = X_train[-validation_size:]
Y_validate = Y_train[-validation_size:]
# X_test = X_test[:-validation_size]
# Y_test = Y_test[:-validation_size]
score,acc = model.evaluate(X_test, Y_test, verbose = 2, batch_size = batch_size)
print("score: %.2f" % (score))
print("acc: %.2f" % (acc))

# %% [markdown]
# Finally measuring the number of correct guesses.  It is clear that finding negative tweets goes very well for the Network but deciding whether is positive is not really. My educated guess here is that the positive training set is dramatically smaller than the negative, hence the "bad" results for positive tweets.

# %%
pos_cnt, neg_cnt, pos_correct, neg_correct = 0, 0, 0, 0
predicted = []
for x in range(len(X_validate)):
    
    result = model.predict(X_validate[x].reshape(1,X_test.shape[1]),batch_size=1,verbose = 2)[0]
    print(result)
   
#     if np.argmax(result) == np.argmax(Y_validate[x]):
    if np.argmax(result) == 0:
        predicted.append([1, 0])
# neg_correct += 1
#             predicted.append([0, 1])
    else:
#         pos_correct += 1
        predicted.append([0, 1])

#             predicted.append([1, 0])
#     if np.argmax(Y_validate[x]) == 0:
#         neg_cnt += 1
#         predicted.append([1, 0])
#     else:
#         pos_cnt += 1
#         predicted.append([0, 1])
        


predicted = np.array(predicted)
# print("pos_acc", pos_correct/pos_cnt*100, "%")
# print("neg_acc", neg_correct/neg_cnt*100, "%")

# %%
def evaluate(target, predicted):
    f1 = f1_score(target, predicted, average='weighted')
    acc = accuracy_score(target, predicted)
    rec = recall_score(target, predicted, average = 'macro')
#     return f1, acc, rec
    print("f1 score: ", f1)
    print("avg recall", rec)    
    print("accuracy", acc)

# %%
evaluate(predicted, Y_test)
# print(Y_validate)
# Out:
# f1 score:  0.7167900063241546
# avg recall 0.6094572899283888
# accuracy 0.722085308056872
